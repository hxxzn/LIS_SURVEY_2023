# %% [markdown]
# ## Module Import

# %%
# !apt-get update
# !apt-get install g++ openjdk-8-jdk python-dev python3-dev
# !pip3 install JPype1-py3
# !pip3 install konlpy
# !JAVA_HOME="C:\Program Files\Java\jdk-13.0.2"
# Out:
# Hit:1 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [591 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# ...

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 21 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 0s (48.2 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import pandas as pd
import numpy as np
import random
import seaborn as sns
from pandas.api.types import CategoricalDtype
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import platform
import konlpy
import nltk
from konlpy.tag import Okt
okt = Okt()
import re
from wordcloud import WordCloud, STOPWORDS
from collections import Counter
from PIL import Image

# %% [markdown]
# ## 전처리

# %% [markdown]
# ### 1. 데이터 불러오기

# %% [markdown]
# GitHub 또는 GoogleDrive 이용해서 데이터 불러오기!!
# 편한 방법 사용하면 될 듯해용 ~

# %% [markdown]
# **GitHub 이용**

# %%
# 데이터 파일 불러오기
import pandas as pd
LIS = pd.read_csv('https://raw.githubusercontent.com/hxxzn/LIS_SURVEY_2023/main/%EB%8D%B0%EC%9D%B4%ED%84%B0/2023_LIS_SURVEY_%EC%9D%91%EB%8B%B5.csv?token=GHSAT0AAAAAACJS536C7HM7H6NLXWOVDSNCZKAYDXQ')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-4-ab2c652658e2> in <cell line: 3>()
#       1 # 데이터 파일 불러오기
#       2 import pandas as pd
# ----> 3 LIS = pd.read_csv('https://raw.githubusercontent.com/hxxzn/LIS_SURVEY_2023/main/%EB%8D%B0%EC%9D%B4%ED%84%B0/2023_LIS_SURVEY_%EC%9D%91%EB%8B%B5.csv?token=GHSAT0AAAAAACJS536C7HM7H6NLXWOVDSNCZKAYDXQ')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# ...

# %% [markdown]
# **GoogleDrive 이용**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 데이터 파일 불러오기
LIS = pd.read_csv('/content/drive/MyDrive/2023_LIS_SURVEY_응답.csv')

# %% [markdown]
# ### 2. 데이터 확인

# %%
# 전체 column명 확인
list(LIS.columns)
# Out:
# ['타임스탬프',
#  '이메일을 적어주세요. ',
#  '성별은 어떻게 되시나요?',
#  '졸업 여부는 어떻게 되시나요?',
#  '입학연도가 어떻게 되시나요? (학번 앞 네자리)',
#  '현재 몇 학년이신가요?',
#  '문헌정보가 아닌 다른 주전공을 이수하고 있습니까? ',
#  '입학연도가 어떻게 되시나요? (학번 앞 네자리).1',
#  '문헌정보가 아닌 다른 주전공을 이수하고 있습니까? .1',
#  'U011) 학부 입학 당시 희망 진로가 있었나요?',
#  'U011.1) 학부 입학 당시 희망 진로는 무엇이었나요? (복수 응답 가능)',
#  'U012) 현재 희망 진로가 있나요?',
#  'U012.1) 현재 희망 진로는 무엇인가요? (복수 응답 가능)',
#  'U012.2) 현재 희망 진로가 없다면 그 이유는 무엇인가요? (복수 응답 가능)',
#  'U013) 학부 입학 당시와 현재의 희망진로가 다르다면, 그 이유가 무엇인가요?  ',
#  'U014) 학부 입학 당시와 현재의 희망진로가 달라진 것에 영향을 준 것은 무엇인가요? ',
#  'U021) 평소 진로에 있어서 고민이 있다면 무엇인가요? (복수 응답 가능)',
#  'U022) 평소 진로 관련 고민을 어떤 방식으로 해결하나요? (복수 응답 가능)',
#  'U111) 문헌정보학과 교육과정에서 가장 흥미있는 주제는 무엇인가요? ',
#  'U112) 문헌정보학과에 추가로 개설 되었으면 하는 교육과정이 있다면 서술해주세요.',
#  'U121) 현재 이수하고 있는(재학 당시 이수한) 다전공이 있나요?',
#  'U121.1) 현재 이수하고 있는(재학 당시 이수한) 다전공은 무엇인가요?',
#  'U121.2) 현재 이수하고 있는(재학 당시 이수한) 다전공은 무엇인가요?',
#  'U121.3) 현재 이수하고 있는(재학 당시 이수한) 다전공은 무엇인가요?',
#  'U121.3) 현재 이수하고 있는(재학 당시 이수한) 다전공은 무엇인가요?.1',
# ...

# %%
# 불필요한 column 정리
LIS = LIS.drop('개인 정보를 제외한 설문 분석 결과가 전체 공개되는 것에 동의하십니까?', axis=1)
LIS = LIS.drop('점수', axis=1)

# %% [markdown]
# ###3. column 정리

# %% [markdown]
# **column 이름 변경**

# %%
LIS.rename(columns = {
# 인적사항
 '이메일을 적어주세요. ' : '이메일',
 '성별은 어떻게 되시나요?' : '성별',
 '졸업 여부는 어떻게 되시나요?' : '졸업여부',
 '입학연도가 어떻게 되시나요? (학번 앞 네자리)' : '입학연도',
 '현재 몇 학년이신가요?' : '학년', #-----2023추가
 '문헌정보가 아닌 다른 주전공을 이수하고 있습니까? ' : '주전공',
 '입학연도가 어떻게 되시나요? (학번 앞 네자리).1' : '대학원입학연도',
 '문헌정보가 아닌 다른 주전공을 이수하고 있습니까? .1' : '대학원주전공',

# 재학생 - 개별질문
 'U011) 학부 입학 당시 희망 진로가 있었나요?' : '입학당시희망진로유무',
 'U011.1) 학부 입학 당시 희망 진로는 무엇이었나요? (복수 응답 가능)' : '입학당시희망진로',
 'U012) 현재 희망 진로가 있나요?' : '현재희망진로유무',
 'U012.1) 현재 희망 진로는 무엇인가요? (복수 응답 가능)' : '현재희망진로',
 'U012.2) 현재 희망 진로가 없다면 그 이유는 무엇인가요? (복수 응답 가능)' : '현재희망진로없는이유',
 'U013) 학부 입학 당시와 현재의 희망진로가 다르다면, 그 이유가 무엇인가요?  ' : '희망진로불일치이유',
 'U014) 학부 입학 당시와 현재의 희망진로가 달라진 것에 영향을 준 것은 무엇인가요? ' : '희망진로불일치영향',
 'U021) 평소 진로에 있어서 고민이 있다면 무엇인가요? (복수 응답 가능)' : '평소진로고민',
 'U022) 평소 진로 관련 고민을 어떤 방식으로 해결하나요? (복수 응답 가능)' : '진로고민해결방법',
# 재학생 - 학과 관련 질문
 'U111) 문헌정보학과 교육과정에서 가장 흥미있는 주제는 무엇인가요? ' : 'U문헌정보학흥미주제',
 'U112) 문헌정보학과에 추가로 개설 되었으면 하는 교육과정이 있다면 서술해주세요.' : 'U추가개설희망과정_주관식',
 'U121) 현재 이수하고 있는(재학 당시 이수한) 다전공이 있나요?' : 'U다전공이수여부',
 'U121.1) 현재 이수하고 있는(재학 당시 이수한) 다전공은 무엇인가요?' : 'U다전공이수종류',
 'U121.2) 현재 이수하고 있는(재학 당시 이수한) 다전공은 무엇인가요?' : 'U다전공단과대',
 'U121.3) 현재 이수하고 있는(재학 당시 이수한) 다전공은 무엇인가요?' : 'U다전공학과1',
 'U121.3) 현재 이수하고 있는(재학 당시 이수한) 다전공은 무엇인가요?.1' : 'U다전공학과2',
 'U121.3) 현재 이수하고 있는(재학 당시 이수한) 다전공은 무엇인가요?.2' : 'U다전공학과3',
 'U121.3) 현재 이수하고 있는(재학 당시 이수한) 다전공은 무엇인가요?.3' : 'U다전공학과4',
 'U121.3) 현재 이수하고 있는(재학 당시 이수한) 다전공은 무엇인가요?.4' : 'U다전공학과5',
 'U121.3) 현재 이수하고 있는(재학 당시 이수한) 다전공은 무엇인가요?.5' : 'U연계전공학과',
 'U121.3) 현재 이수하고 있는(재학 당시 이수한) 다전공은 무엇인가요?.6' : 'U융합전공학과',
 'U121.3) 현재 이수하고 있는(재학 당시 이수한) 다전공은 무엇인가요?.7' : 'U자기설계전공',
 'U121.3) 현재 이수하고 있는(재학 당시 이수한) 다전공은 무엇인가요?.8' : 'U2개이상다전공',
 'U121.4) 해당 다전공을 선택한 이유는 무엇인가요?' : 'U다전공선택이유',
 'U121.5) 다전공을 이수하면서 겪은 어려움 혹은 문제가 있다면 무엇인가요? (복수 응답 가능)' : 'U다전공이수어려움',
 'U121.6) 다전공을 이수하지 않은 이유가 무엇인가요?' : 'U다전공미이수이유',
 'U122) 다전공 이수의 장점은 무엇이라고 생각하시나요? (복수 응답 가능)' : 'U다전공이수장점',
 'U123) 다전공 이수의 단점은 무엇이라고 생각하시나요? (복수 응답 가능)' : 'U다전공이수단점',
 'U124) 취직에 다전공 이수가 도움이 된다고 생각하시나요?' : 'U다전공취직도움',
 'U131) 현재 문헌정보학과에서 취업을 위한 정보 공유가 적절히 이루어지고 있다고 생각하시나요?' : 'U학과취업정보교류정도',
 'U132) 평소 취업 관련 정보를 얻는 방법은 무엇인가요? (복수 응답 가능) ' : 'U취업정보수집방법',
 'U133) 선호하는 취업 정보 공유 방법은 무엇인가요? (복수 응답 가능)' : 'U선호취업정보공유방법',
 'U134) 재학생들과 졸업생들이 정보 교류를 하기에 어떤 방법이 적절하다고 생각하시나요? (복수 응답 가능)' : 'U학과정보교류선호방법',
 'U135) 문헌정보학과에 진로 관련 프로그램이 필요하다면, 어떤 것이 필요하다고 생각하시나요? (복수 응답 가능)' : 'U필요진로관련프로그램',
 'U136) 진로 관련 프로그램과 관련하여 앞의 선지에 언급되지 않은 희망 프로그램을 자유롭게 서술해주세요. (자세한 내용이어도 좋습니다.)' : 'U필요진로관련프로그램_주관식',
 'U137) 문헌정보학과에 취업 강화 프로그램이 필요하다면, 어떤 것이 필요하다고 생각하나요? (복수 응답 가능)' : 'U필요취업강화프로그램',
# 재학생 - 취업 관련 질문
 'U211) 문헌정보학 전공자가 가질 수 있는 진로에는 어떤 것이 있다고 생각하나요? (복수 응답 가능)' : 'U가능진로종류',
 'U212) 문헌정보학 전공자가 가질 수 있는 진로에 대해서 앞의 선지에 언급되지 않은 내용을 자유롭게 서술해 주세요. (자세한 내용이어도 좋습니다.)' : 'U가능진로종류_주관식',
 'U213)  현재 희망하는 진로는 무엇인가요?' : 'U희망근무분야',
 'U213.1) 근무하고 싶은 도서관 유형은 무엇인가요? (복수 응답 가능) ' : 'U희망근무도서관유형',
 'U213.2) 희망 직종은 무엇인가요? (복수 응답 가능)' : 'U희망직무내용',
 'U213.3) 희망 직무 계열은 무엇인가요? ' : 'U희망직무계열',
 'U221) 희망 연봉 수준은 어느 정도인가요?' : 'U희망연봉수준',
 'U231) 희망 진로와 취업을 위해 현재 준비하고 있는 일이 있나요? ' : 'U현재준비유무',
 'U231.1) 희망 진로를 위해 현재 준비하고 있는 일이 무엇인가요? (복수 응답 가능)' : 'U현재준비내용',
 'U231.3) 현재 준비하고 있는 일이 없다면 그 이유는 무엇인가요? (복수 응답 가능)' : 'U준비하지않는이유',
 'U232) 취업 준비 중에 가장 힘들 것 같은 것은 무엇인가요? (복수 응답 가능)' : 'U취업준비어려운점',
 'U241) 직업을 선택할 때 중요하게 생각하는 가치는 무엇인가요? [1순위]' : 'U진로가치1순위',
 'U241) 직업을 선택할 때 중요하게 생각하는 가치는 무엇인가요? [2순위]' : 'U진로가치2순위',
 'U241) 직업을 선택할 때 중요하게 생각하는 가치는 무엇인가요? [3순위]' : 'U진로가치3순위',
# 재학생 - 대학원 관련 질문
 'U311)  대학원 진학을 고려하고 있나요? ' : 'U대학원진학희망여부',
 'U311.1) 어떤 대학원에 진학하고 싶나요?(진학하셨나요?)' : 'U희망진학대학원종류',
 'U311.1) 어떤 세부 전공을 선택하고 싶나요?(선택하셨나요?)' : 'U희망대학원세부전공',
 'U311.1) 어떤 대학원에 진학하고 싶나요?(진학하셨나요?)  ' : 'U진학대학원종류',
 'U311.2) 희망(실제) 대학원 진학 시기는 언제인가요?' : 'U희망대학원진학시기',
 'U311.3) 대학원 진학의 목적은 무엇인가요?(무엇이었나요?) (복수 응답 가능)' : 'U대학원진학목적',
 'U311.4) 대학원 진학 준비 중 어려울 것 같은(어려웠던) 점은 무엇인가요? (복수 응답 가능)' : 'U대학원진학어려움',
 'U311.5) 대학원 진학을 고려하지 않는 이유는 무엇이었나요? (복수 응답 가능)' : 'U대학원진학미고려이유',
}, inplace=True)

# %%
LIS.rename(columns = {
# 졸업생
 '졸업연도가 어떻게 되시나요? (학부 기준)' : '졸업연도',
 '현재 취직을 하셨나요? ' : '취직여부',

# 취직자 - 학과 관련 질문
 'W111) 문헌정보학과 교육과정에서 가장 흥미있는 주제는 무엇이었나요?' : 'W문헌정보학흥미주제',
 'W112) 재학 당시 문헌정보학과에 추가로 개설되었다면 좋았을 것 같은 교육과정에 대해서 서술해주세요.' : 'W추가개설희망과정_주관식',
 'W113) 졸업 후에 도움이 되었던 교육과정은 무엇이었나요? (취업준비/실무 등)' : 'W졸업후도움이된과정',
 'W121) 재학 당시 이수한 다전공이 있나요?' : 'W다전공이수여부',
 'W121.1) 재학 당시 이수한 다전공은 무엇인가요?' : 'W다전공이수종류',
 'W121.2) 재학 당시 이수한 다전공은 무엇인가요?' : 'W다전공단과대',
 'W121.3) 재학 당시 이수한 다전공은 무엇인가요?' : 'W다전공학과1',
 'W121.3) 재학 당시 이수한 다전공은 무엇인가요?.1' : 'W다전공학과2',
 'W121.3) 재학 당시 이수한 다전공은 무엇인가요?.2' : 'W다전공학과3',
 'W121.3) 재학 당시 이수한 다전공은 무엇인가요?.3' : 'W다전공학과4',
 'W121.3) 재학 당시 이수한 다전공은 무엇인가요?.4' : 'W다전공학과5',
 'W121.3) 재학 당시 이수한 다전공은 무엇인가요?.5' : 'W연계전공학과',
 'W121.3) 재학 당시 이수한 다전공은 무엇인가요?.6' : 'W융합전공학과',
 'W121.3) 재학 당시 이수한 다전공은 무엇인가요?.7' : 'W자기설계전공',
 'W121.3) 재학 당시 이수한 다전공은 무엇인가요?.8' : 'W2개이상다전공',
 'W121.4) 해당 다전공을 선택한 이유는 무엇인가요?' : 'W다전공선택이유',
 'W121.5) 다전공을 이수하면서 겪은 어려움 혹은 문제가 있었다면 무엇인가요? (복수 응답 가능)' : 'W다전공이수어려움',
 'W121.6) 재학 당시 다전공을 이수하지 않은 이유가 무엇인가요?' : 'W다전공미이수이유',
 'W122) 다전공 이수의 장점은 무엇이라고 생각하시나요? (복수 응답 가능)' : 'W다전공이수장점',
 'W123) 다전공 이수의 단점은 무엇이라고 생각하시나요? (복수 응답 가능)' : 'W다전공이수단점',
 'W124) 취직에 다전공 이수가 도움이 된다고 생각하시나요?' : 'W다전공취직도움',
 'W125) 취직에 다전공 이수가 도움이 된다고 생각하시는 이유를 서술해주세요.' : 'W다전공취직도움이유_주관식',
 'W131) 문헌정보학과에서 취업을 위한 정보 공유가 적절히 이루어졌다고 생각하시나요?' : 'W학과취업정보교류정도',
 'W132) 취업 관련 정보를 얻었던 방법은 무엇인가요? (복수 응답 가능)' : 'W취업정보수집방법',
 'W133) 선호하는 취업 정보 공유 방법은 무엇인가요? (복수 응답 가능)' : 'W선호취업정보공유방법',
 'W134) 재학생들과 졸업생들이 정보 교류를 하기에 어떤 방법이 적절하다고 생각하시나요? (복수 응답 가능)' : 'W학과정보교류선호방법',
 'W135) 문헌정보학과에 진로 관련 프로그램이 필요하다면, 어떤 것이 필요하다고 생각하시나요? (복수 응답 가능)' : 'W필요진로관련프로그램',
 'W136) 진로 관련 프로그램과 관련하여 앞의 선지에 언급되지 않은 희망 프로그램을 자유롭게 서술해주세요. (자세한 내용이어도 좋습니다.)' : 'W필요진로관련프로그램_주관식',
 'W137) 문헌정보학과에 취업 강화 프로그램이 필요하다면, 어떤 것이 필요하다고 생각하나요? (복수 응답 가능)' : 'W필요취업강화프로그램',
# 취직자 - 취업 관련 질문
' W211) 문헌정보학 전공자가 가질 수 있는 진로에는 어떤 것이 있다고 생각하나요? ' : 'W가능진로종류',
 'W212) 문헌정보학 전공자가 가질 수 있는 진로에 대해서 앞의 선지에 언급되지 않은 내용을 자유롭게 서술해 주세요. (자세한 내용이어도 좋습니다.)' : 'W가능진로종류_주관식',
 'W213) 현재 근무하고 있는 분야가 무엇인가요?' : 'W근무분야',
 ' W213.1) 근무하고 있는 도서관 유형은 무엇인가요? (복수 응답 가능) ' : 'W근무도서관유형',
 'W213.2) 현재 근무 중인 직종은 무엇인가요? (복수 응답 가능)' : 'W현재직무내용',
 'W213.3) 현재 근무 중인 직무 계열은 무엇인가요?' : 'W현재직무계열',
 'W213.4) 현재 근무 중인 분야에 대해 최대한 자세히 작성해주세요.' : 'W현재근무분야_주관식',
 'W221) 실제 연봉 수준은 어느 정도인가요?' : 'W실제연봉수준',
 'W231) 희망 진로와 취업을 위해 과거에 준비했던 일이 있나요?' : 'W과거준비유무',
 'W231.1) 희망 진로와 취업을 위해 준비했던 일이 무엇인가요? (복수 응답 가능)' : 'W과거준비내용',
 'W231.2) 준비했던 일 중 가장 도움이 되었던 것은 무엇인가요?' : 'W가장도움이되었던준비',
 'W231.3) 과거에 준비하고 있던 일이 없었다면 그 이유는 무엇인가요? (복수 응답 가능)' : 'W준비하지않은이유',
 'W232) 취업 준비 중에 가장 힘들었던 것은 무엇인가요? (복수 응답 가능)' : 'W취업준비어려운점',
 'W233) 실제 취업 준비 기간은 어느 정도이었나요?' : 'W취업준비기간',
 'W241) 직업을 선택할 때 중요하게 생각했던 가치는 무엇인가요?  [1순위]' : 'W진로가치1순위', #-----2023추가
 'W241) 직업을 선택할 때 중요하게 생각했던 가치는 무엇인가요?  [2순위]' : 'W진로가치2순위', #-----2023추가
 'W241) 직업을 선택할 때 중요하게 생각했던 가치는 무엇인가요?  [3순위]' : 'W진로가치3순위', #-----2023추가
 'W242) 취직 전후로 직업 가치관의 변화가 있었나요?' : 'W취직전후가치관변화', #-----2023추가
 'W242.1) 취직 후 중요시하게 된 가치는 무엇인가요? [1순위]' : 'W취직후가치1순위', #-----2023추가
 'W242.1) 취직 후 중요시하게 된 가치는 무엇인가요? [2순위]' : 'W취직후가치2순위', #-----2023추가
 'W242.1) 취직 후 중요시하게 된 가치는 무엇인가요? [3순위]' : 'W취직후가치3순위', #-----2023추가
 'W251) 현재 직무 만족도는 어떠한가요?' : 'W현재직무만족도',
 'W252) 현재의 근무지를 문헌정보학과 후배들에게 추천할 의향이 있나요?' : 'W추천의향',
# 취직자 - 대학원 관련 질문
 'W311) 대학원에 진학했나요?' : 'W대학원진학여부',
 'W311.1) 어떤 대학원에 진학하셨나요?' : 'W진학대학원종류',
 'W311.1) 어떤 세부 전공을 선택하셨나요?' : 'W대학원세부전공',
 'W311.1) 어떤 대학원에 진학하셨나요?.1' : 'W진학대학원종류_주관식',
 ' W311.2) 대학원 진학 시기는 언제인가요?' : 'W대학원진학시기',
 'W311.3) 대학원 진학의 목적은 무엇이었나요? (복수 응답 가능)' : 'W대학원진학목적',
 'W311.4) 대학원 진학 준비 중 어려웠던 점은 무엇인가요? (복수 응답 가능)' : 'W대학원진학어려움',
 'W311.5) 대학원 진학을 고려하지 않은 이유는 무엇이었나요? (복수 응답 가능)' : 'W대학원진학미고려이유',
 'W311.6) 향후 대학원에 진학할 의향이 있으신가요?' : 'W진학의향여부',
 'W311.7) 진학할 의향이 있다면 어떤 대학원에 진학할 생각이신가요? (복수 응답 가능)' : 'W향후대학원종류',

# 취준생 - 학과 관련 질문
 'S111) 문헌정보학과 교육과정에서 가장 흥미있는 주제는 무엇이었나요? ' : 'S문헌정보학흥미주제',
 'S112) 재학 당시 문헌정보학과에 추가로 개설되었다면 좋았을 것 같은 교육과정에 대해서 서술해주세요.' : 'S추가개설희망과정_주관식',
 'S113) 졸업 후에 도움이 되었던 교육과정은 무엇이었나요? (취업준비 등)' : 'S졸업후도움이된과정',
 'S121) 재학 당시 이수한 다전공이 있나요?' : 'S다전공이수여부',
 'S121.1) 재학 당시 이수한 다전공은 무엇인가요? ' : 'S다전공이수종류',
 'S121.2) 재학 당시 이수한 다전공은 무엇인가요?' : 'S다전공단과대',
 'S121.3) 재학 당시 이수한 다전공은 무엇인가요?' : 'S다전공학과1',
 'S121.3) 재학 당시 이수한 다전공은 무엇인가요?.1' : 'S다전공학과2',
 'S121.3) 재학 당시 이수한 다전공은 무엇인가요?.2' : 'S다전공학과3',
 'S121.3) 재학 당시 이수한 다전공은 무엇인가요?.3' : 'S다전공학과4',
 'S121.3) 재학 당시 이수한 다전공은 무엇인가요?.4' : 'S다전공학과5',
 'S121.3) 재학 당시 이수한 다전공은 무엇인가요?.5' : 'S연계전공학과',
 'S121.3) 재학 당시 이수한 다전공은 무엇인가요?.6' : 'S융합전공학과',
 'S121.3) 재학 당시 이수한 다전공은 무엇인가요?.7' : 'S자기설계전공',
 'S121.3) 재학 당시 이수한 다전공은 무엇인가요?.8' : 'S2개이상다전공',
 'S121.4) 해당 다전공을 선택한 이유는 무엇인가요?' : 'S다전공선택이유',
 'S121.5 다전공을 이수하면서 겪은 어려움 혹은 문제가 있다면 무엇인가요? (복수 응답 가능)' : 'S다전공이수어려움',
 'S121.6) 재학 당시 다전공을 이수하지 않은 이유가 무엇인가요?' : 'S다전공미이수이유',
 'S122) 다전공 이수의 장점은 무엇이라고 생각하시나요? (복수 응답 가능)' : 'S다전공이수장점',
 'S123) 다전공 이수의 단점은 무엇이라고 생각하시나요? (복수 응답 가능)' : 'S다전공이수단점',
 'S124)  취직 준비에 다전공 이수가 도움이 된다고 생각하시나요? ' : 'S다전공취직도움',
 'S131) 문헌정보학과에서 취업을 위한 정보 공유가 적절히 이루어졌다고 생각하시나요?' : 'S학과취업정보교류정도',
 'S132) 평소 취업 관련 정보를 얻는 방법은 무엇인가요? (복수 응답 가능)' : 'S취업정보수집방법',
 'S133) 선호하는 취업 정보 공유 방법은 무엇인가요? (복수 응답 가능)' : 'S선호취업정보공유방법',
 'S134) 재학생들과 졸업생들이 정보 교류를 하기에 어떤 방법이 적절하다고 생각하시나요? (복수응답 가능)' : 'S학과정보교류선호방법',
 'S135) 문헌정보학과에 진로 관련 프로그램이 필요하다면, 어떤 것이 필요하다고 생각하시나요? (복수 응답 가능)' : 'S필요진로관련프로그램',
 'S136) 진로 관련 프로그램과 관련하여 앞의 선지에 언급되지 않은 희망 프로그램을 자유롭게 서술해주세요. (자세한 내용이어도 좋습니다.)' : 'S필요진로관련프로그램_주관식',
 'S137) 문헌정보학과에 취업 강화 프로그램이 필요하다면, 어떤 것이 필요하다고 생각하나요? (복수 응답 가능)' : 'S필요취업강화프로그램',
 # 취준생 - 취업 관련 질문
 'S211) 문헌정보학 전공자가 가질 수 있는 진로에는 어떤 것이 있다고 생각하나요? ' : 'S가능진로종류',
 'S212) 문헌정보학 전공자가 가질 수 있는 진로에 대해서 앞의 선지에 언급되지 않은 내용을 자유롭게 서술해 주세요. (자세한 내용이어도 좋습니다.)' : 'S가능진로종류_주관식',
 'S213) 현재 희망하는 진로는 무엇인가요?' : 'S희망근무분야',
 ' S213.1) 근무하고 싶은 도서관 유형은 무엇인가요? (복수 응답 가능) ' : 'S희망근무도서관유형',
 'S213.2) 희망 직종은 무엇인가요? (복수 응답 가능)' : 'S희망직무내용',
 'S213.3) 희망 직무 계열은 무엇인가요? ' : 'S희망직무계열',
 'S221) 희망 연봉 수준은 어느 정도인가요?' : 'S희망연봉수준',
 'S231) 희망 진로와 취업을 위해 현재 준비하고 있는 일이 있나요?' : 'S현재준비유무',
 'S231.1) 희망 진로와 취업을 위해 현재 준비하고 있는 일이 무엇인가요? (복수 응답 가능)' : 'S현재준비내용',
 'S231.3) 현재 준비하고 있는 일이 없다면 그 이유는 무엇인가요? (복수 응답 가능)' : 'S준비하지않는이유',
 'S232) 취업 준비 중에 가장 힘든 것은 무엇인가요? (복수 응답 가능)' : 'S취업준비어려운점',
 'S241) 직업을 선택할 때 중요하게 생각하는 가치는 무엇인가요?  [1순위]' : 'S진로가치1순위',
 'S241) 직업을 선택할 때 중요하게 생각하는 가치는 무엇인가요?  [2순위]' : 'S진로가치2순위',
 'S241) 직업을 선택할 때 중요하게 생각하는 가치는 무엇인가요?  [3순위]' : 'S진로가치3순위',
# 취준생 - 대학원 관련 질문
 'S311) 대학원에 진학했나요?' : 'S대학원진학여부',
 'S311.1) 어떤 대학원에 진학하셨나요?' : 'S진학대학원종류',
 'S311.1) 어떤 세부 전공을 선택하셨나요?' : 'S대학원세부전공',
 'S311.1) 어떤 대학원에 진학하셨나요?.1' : 'S진학대학원종류_주관식',
 ' S311.2) 대학원 진학 시기는 언제인가요?' : 'S대학원진학시기',
 'S311.3) 대학원 진학의 목적은 무엇이었나요? (복수 응답 가능)' : 'S대학원진학목적',
 'S311.4) 대학원 진학 준비 중 어려웠던 점은 무엇인가요? (복수 응답 가능)' : 'S대학원진학어려움',
 'S311.5) 대학원 진학을 고려하지 않은 이유는 무엇이었나요? (복수 응답 가능)' : 'S대학원진학미고려이유',
 'S311.6) 향후 대학원에 진학할 의향이 있으신가요?' : 'S진학의향여부',
 'S311.7) 진학할 의향이 있다면 어떤 대학원에 진학할 생각이신가요? (복수 응답 가능)' : 'S향후대학원종류'
 }, inplace=True)

# %%
# column명 변경 확인
list(LIS.columns)
# Out:
# ['타임스탬프',
#  '이메일',
#  '성별',
#  '졸업여부',
#  '입학연도',
#  '학년',
#  '주전공',
#  '대학원입학연도',
#  '대학원주전공',
#  '입학당시희망진로유무',
#  '입학당시희망진로',
#  '현재희망진로유무',
#  '현재희망진로',
#  '현재희망진로없는이유',
#  '희망진로불일치이유',
#  '희망진로불일치영향',
#  '평소진로고민',
#  '진로고민해결방법',
#  'U문헌정보학흥미주제',
#  'U추가개설희망과정_주관식',
#  'U다전공이수여부',
#  'U다전공이수종류',
#  'U다전공단과대',
#  'U다전공학과1',
#  'U다전공학과2',
#  'U다전공학과3',
#  'U다전공학과4',
#  'U다전공학과5',
#  'U연계전공학과',
#  'U융합전공학과',
#  'U자기설계전공',
#  'U2개이상다전공',
#  'U다전공선택이유',
#  'U다전공이수어려움',
#  'U다전공미이수이유',
#  'U다전공이수장점',
#  'U다전공이수단점',
#  'U다전공취직도움',
#  'U학과취업정보교류정도',
#  'U취업정보수집방법',
#  'U선호취업정보공유방법',
#  'U학과정보교류선호방법',
#  'U필요진로관련프로그램',
#  'U필요진로관련프로그램_주관식',
#  'U필요취업강화프로그램',
#  'U가능진로종류',
#  'U가능진로종류_주관식',
#  'U희망근무분야',
#  'U희망근무도서관유형',
#  'U희망직무내용',
#  'U희망직무계열',
#  'U희망연봉수준',
#  'U현재준비유무',
#  'U현재준비내용',
#  'U준비하지않는이유',
#  'U취업준비어려운점',
#  'U진로가치1순위',
#  'U진로가치2순위',
#  'U진로가치3순위',
#  'U대학원진학희망여부',
#  'U희망진학대학원종류',
#  'U희망대학원세부전공',
#  'U진학대학원종류',
#  'U희망대학원진학시기',
#  'U대학원진학목적',
#  'U대학원진학어려움',
# ...

# %% [markdown]
# **column 합치고 순서 재정렬**

# %%
# column 위치 확인
print(LIS.columns.get_loc('U다전공학과1'))
# Out:
# 23

# %%
# 재학생
LIS['U다전공학과'] = LIS['U다전공학과1'].astype(str) + LIS['U다전공학과2'].astype(str) + LIS['U다전공학과3'].astype(str) + LIS['U다전공학과4'].astype(str) + LIS['U다전공학과5'].astype(str)
LIS['U다전공학과'] = LIS['U다전공학과'].str.strip('nan')
LIS = LIS.drop(['U다전공학과1', 'U다전공학과2', 'U다전공학과3', 'U다전공학과4', 'U다전공학과5'], axis=1)
cols = LIS.columns.tolist()
cols.insert(23, cols.pop(cols.index('U다전공학과')))
LIS = LIS[cols]

# %%
print(LIS.columns.get_loc('W다전공학과1'))
# Out:
# 71

# %%
# 취업자
LIS['W다전공학과'] = LIS['W다전공학과1'].astype(str) + LIS['W다전공학과2'].astype(str)+ LIS['W다전공학과3'].astype(str) + LIS['W다전공학과4'].astype(str) + LIS['W다전공학과5'].astype(str)
LIS['W다전공학과'] = LIS['W다전공학과'].str.strip('nan')
LIS = LIS.drop(['W다전공학과1', 'W다전공학과2', 'W다전공학과3', 'W다전공학과4', 'W다전공학과5'], axis=1)
cols = LIS.columns.tolist()
cols.insert(71, cols.pop(cols.index('W다전공학과')))
LIS = LIS[cols]

# %%
print(LIS.columns.get_loc('S다전공학과1'))
# Out:
# 129

# %%
# 취준생
LIS['S다전공학과'] = LIS['S다전공학과1'].astype(str) + LIS['S다전공학과2'].astype(str) + LIS['S다전공학과3'].astype(str) + LIS['S다전공학과4'].astype(str) + LIS['S다전공학과5'].astype(str)
LIS['S다전공학과'] = LIS['S다전공학과'].str.strip('nan')
LIS = LIS.drop(['S다전공학과1', 'S다전공학과2', 'S다전공학과3', 'S다전공학과4', 'S다전공학과5'], axis=1)
cols = LIS.columns.tolist()
cols.insert(129, cols.pop(cols.index('S다전공학과')))
LIS = LIS[cols]

# %%
# column 정리 확인
list(LIS.columns)
# Out:
# ['타임스탬프',
#  '이메일',
#  '성별',
#  '졸업여부',
#  '입학연도',
#  '학년',
#  '주전공',
#  '대학원입학연도',
#  '대학원주전공',
#  '입학당시희망진로유무',
#  '입학당시희망진로',
#  '현재희망진로유무',
#  '현재희망진로',
#  '현재희망진로없는이유',
#  '희망진로불일치이유',
#  '희망진로불일치영향',
#  '평소진로고민',
#  '진로고민해결방법',
#  'U문헌정보학흥미주제',
#  'U추가개설희망과정_주관식',
#  'U다전공이수여부',
#  'U다전공이수종류',
#  'U다전공단과대',
#  'U다전공학과',
#  'U연계전공학과',
#  'U융합전공학과',
#  'U자기설계전공',
#  'U2개이상다전공',
#  'U다전공선택이유',
#  'U다전공이수어려움',
#  'U다전공미이수이유',
#  'U다전공이수장점',
#  'U다전공이수단점',
#  'U다전공취직도움',
#  'U학과취업정보교류정도',
#  'U취업정보수집방법',
#  'U선호취업정보공유방법',
#  'U학과정보교류선호방법',
#  'U필요진로관련프로그램',
#  'U필요진로관련프로그램_주관식',
#  'U필요취업강화프로그램',
#  'U가능진로종류',
#  'U가능진로종류_주관식',
#  'U희망근무분야',
#  'U희망근무도서관유형',
#  'U희망직무내용',
#  'U희망직무계열',
#  'U희망연봉수준',
#  'U현재준비유무',
#  'U현재준비내용',
#  'U준비하지않는이유',
#  'U취업준비어려운점',
#  'U진로가치1순위',
#  'U진로가치2순위',
#  'U진로가치3순위',
#  'U대학원진학희망여부',
#  'U희망진학대학원종류',
#  'U희망대학원세부전공',
#  'U진학대학원종류',
#  'U희망대학원진학시기',
#  'U대학원진학목적',
#  'U대학원진학어려움',
#  'U대학원진학미고려이유',
#  '졸업연도',
#  '취직여부',
#  'W문헌정보학흥미주제',
# ...

# %% [markdown]
# ###4. 파트별 데이터 프레임 생성

# %% [markdown]
# **학부 재학생**

# %%
# 학부 재학생 데이터 프레임
Ustudent = LIS[LIS['졸업여부'] == '학부 재학생']
Uindex1 = LIS.columns.get_loc('주전공')
Uindex2 = LIS.columns.get_loc('입학당시희망진로유무')
Uindex3 = LIS.columns.get_loc('U대학원진학미고려이유')
Ustudent = Ustudent.iloc[:, list(range(0, Uindex1+1)) + list(range(Uindex2, Uindex3+1))]

# %%
# 인덱스 초기화
Ustudent.reset_index(drop=True,inplace=True)

# %%
# 연도 자료형 변경
Ustudent['입학연도'] = Ustudent['입학연도'].astype(int)
Ustudent['입학연도'] = Ustudent['입학연도'].astype(str)

# %%
# 데이터 확인
Ustudent
# Out:
#                        타임스탬프                    이메일     성별    졸업여부  입학연도  \
# 0     2023. 10. 4 오후 4:46:45     grin2614@naver.com     여성  학부 재학생  2021
# 1     2023. 10. 4 오후 4:50:56      HJM1402@gmail.com     남성  학부 재학생  2023
# 2     2023. 10. 4 오후 5:04:04                      ㅇ  선택 안함  학부 재학생  2023
# 3     2023. 10. 4 오후 5:08:30   zjongho123@gmail.com     남성  학부 재학생  2021
# 4     2023. 10. 4 오후 5:13:47    hyeni0211@gmail.com     여성  학부 재학생  2023
# ..                       ...                    ...    ...     ...   ...
# 62  2023. 10. 15 오전 11:49:23     5532625t@naver.com     여성  학부 재학생  2023
# 63  2023. 10. 15 오후 12:17:51      jeyolim@naver.com     여성  학부 재학생  2021
# 64   2023. 10. 15 오후 1:55:12       lucyle@naver.com     여성  학부 재학생  2021
# 65   2023. 10. 15 오후 2:26:22     cabbyto2@naver.com     여성  학부 재학생  2021
# 66  2023. 10. 16 오전 12:25:45  whgustj6790@naver.com     여성  학부 재학생  2020
#
#                학년  주전공 입학당시희망진로유무  \
# 0   3학년 (5~6차 학기)  아니오          예
# ...

# %% [markdown]
# **대학원 재학생**

# %%
# 대학원 재학생 데이터 프레임
Gstudent = LIS[LIS['졸업여부'] == '대학원 재학생']
Gindex1 = LIS.columns.get_loc('졸업여부')
Gindex2 = LIS.columns.get_loc('대학원입학연도')
Gindex3 = LIS.columns.get_loc('U대학원진학미고려이유')
Gstudent = Gstudent.iloc[:, list(range(0, Gindex1+1)) + list(range(Gindex2, Gindex3+1))]

# %%
# 인덱스 초기화
Gstudent.reset_index(drop=True,inplace=True)

# %%
# 연도 자료형 변경
Gstudent['대학원입학연도'] = Gstudent['대학원입학연도'].astype(int)
Gstudent['대학원입학연도'] = Gstudent['대학원입학연도'].astype(str)

# %%
# 데이터 확인
Gstudent
# Out:
#                       타임스탬프                         이메일  성별     졸업여부 대학원입학연도  \
# 0  2023. 10. 10 오전 10:49:41       euntaekseon@gmail.com  여성  대학원 재학생    2018
# 1  2023. 10. 10 오전 10:54:00       givemetarte@naver.com  여성  대학원 재학생    2017
# 2   2023. 10. 10 오후 1:04:10           lunamin@cau.ac.kr  여성  대학원 재학생    2021
# 3   2023. 10. 10 오후 1:35:23  chaeeunsong.hike@gmail.com  여성  대학원 재학생    2016
# 4   2023. 10. 11 오후 5:23:42         clayflute@gmail.com  남성  대학원 재학생    2016
# 5   2023. 10. 11 오후 5:57:32         digup0124@gmail.com  여성  대학원 재학생    2017
#
#   대학원주전공 입학당시희망진로유무                                           입학당시희망진로  \
# 0    아니오          예                                            데이터 전문가
# 1    아니오        아니오                                                NaN
# 2    아니오        아니오                                                NaN
# 3    아니오          예  사서직 (공무원/대학 및 전문 도서관 사서 포함), 사서 교사, 출판업, 일반 사기...
# 4    아니오          예  사서직 (공무원/대학 및 전문 도서관 사서 포함), 사서 교사, 기록물 관리사, 대...
# ...

# %% [markdown]
# **취업자**

# %%
# 취업자 데이터 프레임
worker = LIS[LIS['취직여부'] == '예']
Windex1 = LIS.columns.get_loc('졸업여부')
Windex2 = LIS.columns.get_loc('졸업연도')
Windex3 = LIS.columns.get_loc('W향후대학원종류')
worker = worker.iloc[:, list(range(0, Windex1+1)) + list(range(Windex2, Windex3+1))]

# %%
# 인덱스 초기화
worker.reset_index(drop=True,inplace=True)

# %%
# 연도 자료형 변경
worker['졸업연도'] = worker['졸업연도'].astype(int)
worker['졸업연도'] = worker['졸업연도'].astype(str)

# %%
# 데이터 확인
worker
# Out:
#                        타임스탬프                     이메일  성별 졸업여부  졸업연도 취직여부  \
# 0   2023. 10. 10 오전 11:00:12         mumbb@naver.com  여성  졸업생  2021    예
# 1   2023. 10. 10 오후 12:49:03      yjlee301@naver.com  여성  졸업생  2020    예
# 2   2023. 10. 10 오후 12:49:58      wjdyejin@naver.com  여성  졸업생  2020    예
# 3    2023. 10. 10 오후 1:13:44      yeon3864@naver.com  여성  졸업생  2020    예
# 4    2023. 10. 10 오후 1:14:59      co002002@naver.com  여성  졸업생  2020    예
# 5    2023. 10. 10 오후 1:35:20      shin3924@naver.com  여성  졸업생  2019    예
# 6    2023. 10. 10 오후 1:39:50      a971021a@naver.com  여성  졸업생  2021    예
# 7    2023. 10. 11 오후 1:55:37    belief@hanyang.ac.kr  여성  졸업생  2022    예
# 8    2023. 10. 11 오후 6:00:58   yujiney@hanyang.ac.kr  여성  졸업생  2021    예
# 9    2023. 10. 11 오후 6:12:50  adastra37127@gmail.com  남성  졸업생  2022    예
# 10   2023. 10. 11 오후 6:21:54       sh__ine@naver.com  여성  졸업생  2021    예
# 11   2023. 10. 11 오후 6:55:17   doyeon00219@naver.com  여성  졸업생  2021    예
# ...

# %% [markdown]
# **취준생**

# %%
# 취준생 데이터 프레임
seeker = LIS[LIS['취직여부'] == '아니오']
Sindex1 = LIS.columns.get_loc('졸업여부')
Sindex2 = LIS.columns.get_loc('졸업연도')
Sindex3 = LIS.columns.get_loc('취직여부')
Sindex4 = LIS.columns.get_loc('S문헌정보학흥미주제')
Sindex5 = len(LIS.columns)
seeker = seeker.iloc[:, list(range(0, Sindex1+1)) + list(range(Sindex2, Sindex3+1)) + list(range(Sindex4, Sindex5))]

# %%
# 인덱스 초기화
seeker.reset_index(drop=True,inplace=True)

# %%
# 연도 자료형 변경
seeker['졸업연도'] = seeker['졸업연도'].astype(int)
seeker['졸업연도'] = seeker['졸업연도'].astype(str)

# %%
# 데이터 확인
seeker
# Out:
#                       타임스탬프                     이메일     성별 졸업여부  졸업연도 취직여부  \
# 0    2023. 10. 6 오후 6:01:26        sul412@naver.com     여성  졸업생  2023  아니오
# 1  2023. 10. 10 오후 12:52:05    nunice2080@naver.com     여성  졸업생  2020  아니오
# 2   2023. 10. 11 오후 1:36:08  candypark415@naver.com     여성  졸업생  2023  아니오
# 3   2023. 10. 11 오후 6:31:44       yjk1322@naver.com  선택 안함  졸업생  2021  아니오
# 4   2023. 10. 11 오후 7:02:03    hellow0716@naver.com     남성  졸업생  2023  아니오
# 5   2023. 10. 11 오후 7:32:42   xhvksptm428@naver.com     여성  졸업생  2022  아니오
# 6   2023. 10. 13 오후 5:33:47      sooy2209@naver.com     여성  졸업생  2023  아니오
#
#                     S문헌정보학흥미주제                S추가개설희망과정_주관식  \
# 0                          NaN                          NaN
# 1  자료조직 (문헌분류론/문헌목록법/자료조직연습 등)                   코딩 관련 교육과정
# 2     도서관경영 (도서관경영론/도서관마케팅론 등)                     학교도서관경영론
# 3     도서관경영 (도서관경영론/도서관마케팅론 등)                          NaN
# 4     도서관경영 (도서관경영론/도서관마케팅론 등)                          NaN
# ...

# %% [markdown]
# ## 함수 설정

# %% [markdown]
# 답변 정리 후 데이터 프레임 만들기

# %%
def count_to(series, name):

    # 시리즈 복사 - 원본 데이터 유지
    series_copy = series.copy()
    # 결측값 제거
    series_copy.dropna(inplace=True)
    # 시리즈를 리스트로 변환
    first_list = series_copy.tolist()

    # 쪼개야 할 단어들을 찾아서 리스트에서 제거하고 각 단어를 쪼갠 뒤 리스트에 추가
    words_to_split = [word for word in first_list if ',' in str(word)]
    for word in words_to_split:
        first_list.remove(word)
        first_list.extend(word.split(','))

    # 중복을 제거한 고유한 단어들의 리스트 생성
    unique_words = list(set(first_list))
    # 각 고유한 단어의 출현 빈도 리스트에 저장
    counts = [first_list.count(word) for word in unique_words]

    # 단어와 출현 빈도로 데이터프레임 생성
    count_df = pd.DataFrame({name: unique_words, '카운트': counts})
    # 출현 빈도에 따라 내림차순으로 데이터프레임 정렬
    count_df = count_df.sort_values('카운트', ascending=False).reset_index(drop=True)

    # 정렬된 데이터프레임 반환
    return count_df

# %% [markdown]
# 예외 처리 함수 - 같은 선택지 다르게 카운트 되는 경우

# %%
def count_to_outlier(df, column):
    # 공백을 제거한 리스트 생성
    tmp_list = [i.strip() for i in df[column]]
    # 데이터프레임의 열을 업데이트
    df[column] = tmp_list
    # 공백을 제거한 값에 기반하여 그룹화하고 합계 계산
    df = df.groupby(column).size().reset_index(name='카운트')

    return df

# %%
def count_to_outlier2(df, column):
    # 공백을 제거한 리스트 생성
    tmp_list = [i.strip() for i in df[column]]
    # 데이터프레임의 열을 업데이트
    df[column] = tmp_list
    # 공백을 제거한 값에 기반하여 그룹화하고 합계 계산
    df = df.groupby(column).sum()

    return df

# %% [markdown]
# 구분 / 퍼센트 추가 함수

# %%
def add_classes(df, name, ex_column, new_column):
    # 데이터프레임의 인덱스 재설정
    df.reset_index(drop=True, inplace=True)
    # '구분' 열에 'name' 값을 할당
    df['구분'] = name
    per = []
    # 각 행에 대해 '카운트'의 비율을 계산하여 '퍼센트(%)' 열에 추가
    for i in range(0, len(df)):
        per.append(round(df['카운트'].loc[i] / df['카운트'].sum() * 100, 2))
    df['퍼센트(%)'] = per
    # 열 이름 변경
    df.rename(columns={ex_column: new_column}, inplace=True)
    # '퍼센트(%)' 열을 기준으로 내림차순 정렬
    df.sort_values(by='퍼센트(%)', ascending=False, inplace=True)
    return df

# %% [markdown]
# 데이터 프레임 기반 차트 출력 함수 - 레이아웃 미지정

# %%
import plotly.express as px

# %%
def create_chart(dfs, theme):

    # 그래프 스타일 설정
    new = ['#FFCE9A', '#FFC4B6', '#FAC1C8', '#D9C0CB', '#BBABC3', '#929AB8', '#628BA6', '#337C89']

    # 그래프 생성
    fig = px.bar(dfs, x="퍼센트(%)", y="구분", color=theme, orientation='h', text='퍼센트(%)',
                 height=300, color_discrete_sequence=new, custom_data=['카운트', theme])

    # 레이아웃 설정
    fig.update_layout(xaxis_tickfont_size=10,
                      legend=dict(yanchor="top", y=1.35, xanchor="left", x=0.0, orientation="h", font_size=10),
                      yaxis={'visible': True, 'showticklabels': True, 'title': ''},
                      xaxis={'visible': False, 'showticklabels': False},
                      showlegend=True, font=dict(size=10, color="black"), margin=dict(l=2, r=2),
                      plot_bgcolor='rgba(0, 0, 0, 0)', paper_bgcolor='rgba(0,0,0,0)')

    # 표시되는 값 설정
    fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside', textfont_size=14)

    # 호버링 설정
    fig.update_traces(hovertemplate='<br>%{customdata[1]}</br>응답 건수: %{customdata[0]} 건 <br>')

    # 그래프 출력
    fig.show()

    # html 변환
    fig.write_html("%s.html" % theme)

# %% [markdown]
# 데이터 프레임 기반 차트 출력 함수 - 레이아웃 지정

# %%
def create_chart_layout(dfs,theme):

    # 그래프 생성
    fig = px.bar(dfs, x="퍼센트(%)", y="구분", color=theme, orientation='h', text='퍼센트(%)',
          color_discrete_sequence=[px.colors.sequential.deep[7],px.colors.sequential.deep[1]],
          custom_data=['카운트',theme])

    # 레이아웃 설정
    fig.update_layout(xaxis_tickfont_size=10,
                    legend=dict(yanchor="top", y=1.25, xanchor="left",x=0.0,orientation="h",font_size=12, font_color='black'),
                    yaxis={'visible': True, 'showticklabels': True,  'title':''},
                    xaxis={'visible': False, 'showticklabels': False}, height=300,
                    showlegend=True, font=dict(size=10, color="black"),margin=dict(l=2, r=2),
                    plot_bgcolor='rgba(0, 0, 0, 0)', paper_bgcolor = 'rgba(0,0,0,0)')

    # 텍스트 설정
    fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside',textfont_size=12 )
    #fig.update_traces(hovertemplate='<br>%{customdata[1]}</br> %{y}의 %{x} % <br> 응답 건수: %{customdata[0]} 건 <br>' )
    fig.update_traces(hovertemplate='<br>%{customdata[1]}</br>응답 건수: %{customdata[0]} 건 <br>' )
    #fig.for_each_trace(lambda t: t.update(name=t.name.split("=")[1]))

    # 그래프 출력
    fig.show()

    # html 변환
    fig.write_html("%s.html"%theme)

# %% [markdown]
# **매우 그렇다 - 매우 아니다 유형 그래프 함수**

# %%
import plotly.graph_objects as go

# %%
def likert_graph(df, theme, order):

    # 퍼센트 값 계산
    a = pd.pivot_table(
        df,
        index='구분',
        columns=theme,
        values='퍼센트(%)')
    a = a[order]  # 순서 정렬
    a.sort_values(by='구분', ascending=False, inplace=True)

    # 카운트 계산
    b = pd.pivot_table(
        df,
        index='구분',
        columns=theme,
        values='카운트')
    b = b[order]
    b.sort_values(by='구분', ascending=False, inplace=True)

    # 그래프 색상 코드 지정
    colors = ['#FFCE9A', '#FFC4B6', '#FAC1C8', '#D9C0CB', '#BBABC3', '#929AB8', '#628BA6', '#337C89']

    # flotly 생성
    fig = go.Figure()
    for column, color, bcol in zip(a.columns, colors, b.columns):
        fig.add_trace(go.Bar(
            x=a[column],
            y=a.index,
            name=column,
            customdata=b[[bcol]],
            orientation='h',
            marker_color=color,
            hovertemplate=
            "<b>{}:</b><br>".format(column) +
            "응답자수: %{customdata:,}명" +
            "<extra></extra>"), )

    # 레이아웃 설정
    fig.update_layout(barmode='stack',
                      yaxis={'visible': True, 'showticklabels': True, 'title': ''},
                      xaxis={'visible': False, 'showticklabels': False}, height=350,
                      showlegend=True,
                      plot_bgcolor='rgba(0, 0, 0, 0)', paper_bgcolor='rgba(0,0,0,0)', margin=dict(l=2, r=2),
                      legend=dict(yanchor="top", y=1.25, xanchor="left", x=0.0, orientation="h", font_size=12))
    fig.update_traces(texttemplate='%{x:.2f}%', textposition='inside', textfont_size=14)

    # 그래프 출력
    fig.show()

    # html 변환
    fig.write_html("%s.html" % theme)

# %% [markdown]
# **Scatter 그래프 함수**

# %%
def scatter_plot(df, x_axis, y_axis, size_num, name):

    # 그래프 생성
    fig = px.scatter(df, x=x_axis, y=y_axis, color=x_axis, size='카운트', size_max=size_num,
                     color_discrete_sequence=px.colors.sequential.deep[2:], custom_data=['카운트'])

    # 레이아웃 설정
    fig.update_layout(height=500, width=700,
                      xaxis=dict(title='', showgrid=True, zeroline=True, showline=True, showticklabels=True),
                      yaxis=dict(title='', showgrid=True, zeroline=True, showline=True, showticklabels=True),
                      autosize=False, showlegend=False, plot_bgcolor='rgba(0,0,0,0)',
                      margin=dict(l=2, r=4), paper_bgcolor='rgba(0,0,0,0)',
                      legend=dict(yanchor="top", y=1.05, xanchor="left", x=0.0, orientation="h", font_size=12))

    # 축 설정
    fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='rgba(0,0,0,0)')
    fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='rgba(0,0,0,0)')

    # 호버링
    fig.update_traces(hovertemplate='<br>%{x|%Y/%m}</br>%{y}</br>응답 건수: %{customdata[0]} 건 <br>')

    # 출력
    fig.show()

    # html 변환
    fig.write_html("%s.html" % name)

# %%
new= [px.colors.sequential.deep[0],px.colors.sequential.deep[2],px.colors.sequential.deep[4],
        px.colors.sequential.deep[5], px.colors.sequential.deep[7], px.colors.sequential.deep[8], px.colors.sequential.deep[9], px.colors.sequential.deep[1]]

# %% [markdown]
# # 참여자정보

# %% [markdown]
# **(a) 학부 재학생 입학연도 구분**

# %%
#학부 재학생
Uenter_year = count_to(Ustudent['입학연도'], '입학연도')
Uenter_year['구분'] = '학부 재학생'
Uenter_year['카운트'] = Uenter_year['카운트'].astype(int)
Uenter_year = add_classes(Uenter_year, '학부 재학생', '입학연도','입학연도')
Uenter_year = Uenter_year.sort_values('입학연도', ascending=True)
Uenter_year
# Out:
#    입학연도  카운트      구분  퍼센트(%)
# 6  2017    3  학부 재학생    4.48
# 5  2018    4  학부 재학생    5.97
# 2  2019   10  학부 재학생   14.93
# 3  2020   10  학부 재학생   14.93
# 1  2021   15  학부 재학생   22.39
# 4  2022    9  학부 재학생   13.43
# 0  2023   16  학부 재학생   23.88

# %%
make_color=[px.colors.sequential.deep[9],px.colors.sequential.deep[8],px.colors.sequential.deep[7],px.colors.sequential.deep[6],px.colors.sequential.deep[5],
        px.colors.sequential.deep[4],px.colors.sequential.deep[3], px.colors.sequential.deep[2], px.colors.sequential.deep[1], px.colors.sequential.deep[0]]

fig = px.bar(Uenter_year, x='퍼센트(%)', y="구분", color='입학연도', orientation='h',
             color_discrete_sequence=make_color,
             text='입학연도',
             custom_data=Uenter_year[['카운트','입학연도']])

fig.update_layout(height=220,title={'text': '설문에 참여한 입학연도별 학부 재학생 수','y':0.90,'x':0.45,},
                  title_font=dict(size=15,color='black'),
                  yaxis={'visible': False, 'showticklabels': False},
                  xaxis={'visible': False, 'showticklabels': False},
                  plot_bgcolor="#FFFFFF")

fig.update_traces(textposition='inside')
fig.update_traces(hovertemplate='%{customdata[1]}<br>재학생 응답자의 %{x} % <br>응답자수: %{customdata[0]} 명')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_html("연도별_학부재학생수.html")

# %%
create_chart(Uenter_year, '입학연도')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **(b) 대학원 재학생 입학연도 구분**

# %%
#대학원 재학생
Genter_year = count_to(Gstudent['대학원입학연도'], '대학원 입학연도')
Genter_year['구분'] = '대학원 재학생'
Genter_year['카운트'] = Genter_year['카운트'].astype(int)
Genter_year = add_classes(Genter_year, '대학원 재학생', '대학원 입학연도','대학원 입학연도')
Genter_year = Genter_year.sort_values('대학원 입학연도', ascending=True)
Genter_year
# Out:
#   대학원 입학연도  카운트       구분  퍼센트(%)
# 1     2016    2  대학원 재학생   33.33
# 0     2017    2  대학원 재학생   33.33
# 3     2018    1  대학원 재학생   16.67
# 2     2021    1  대학원 재학생   16.67

# %%
make_color=[px.colors.sequential.deep[9],px.colors.sequential.deep[8],px.colors.sequential.deep[7],px.colors.sequential.deep[6],px.colors.sequential.deep[5],
        px.colors.sequential.deep[4],px.colors.sequential.deep[3], px.colors.sequential.deep[2], px.colors.sequential.deep[1], px.colors.sequential.deep[0]]

fig = px.bar(Genter_year, x='퍼센트(%)', y="구분", color='대학원 입학연도', orientation='h',
             color_discrete_sequence=make_color,
             text='대학원 입학연도',
             custom_data=Genter_year[['카운트','대학원 입학연도']])

fig.update_layout(height=220,title={'text': '설문에 참여한 입학연도별 대학원 재학생 수','y':0.90,'x':0.45,},
                  title_font=dict(size=15,color='black'),
                  yaxis={'visible': False, 'showticklabels': False},
                  xaxis={'visible': False, 'showticklabels': False},
                  plot_bgcolor="#FFFFFF")

fig.update_traces(textposition='inside')
fig.update_traces(hovertemplate='%{customdata[1]}<br>재학생 응답자의 %{x} % <br>응답자수: %{customdata[0]} 명')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_html("연도별_대학원재학생수.html")

# %%
create_chart(Genter_year, '대학원 입학연도')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **(c) 졸업생 졸업연도 + 재학생 입학연도**

# %%
#졸업생
graduate_year = count_to(LIS['졸업연도'], '졸업연도')
graduate_year['구분'] = '졸업생'
graduate_year['졸업연도'] = graduate_year['졸업연도'].astype(int)
graduate_year['카운트'] = graduate_year['카운트'].astype(int)
graduate_year = add_classes(graduate_year, '졸업생', '졸업연도','졸업연도')
graduate_year = graduate_year.sort_values('졸업연도', ascending=True)
graduate_year
# Out:
#    졸업연도  카운트   구분  퍼센트(%)
# 4  2019    1  졸업생    4.76
# 0  2020    6  졸업생   28.57
# 1  2021    6  졸업생   28.57
# 3  2022    3  졸업생   14.29
# 2  2023    5  졸업생   23.81

# %%
main=pd.pivot_table(LIS, index=['취직여부','졸업연도'], values=['타임스탬프'], aggfunc='count')
main.reset_index(inplace=True)
main['졸업연도']=main['졸업연도'].astype(int)
main=main.sort_values('졸업연도', ascending=False)

main
# Out:
#   취직여부  졸업연도  타임스탬프
# 3  아니오  2023      4
# 8    예  2023      1
# 2  아니오  2022      1
# 7    예  2022      2
# 1  아니오  2021      1
# 6    예  2021      5
# 0  아니오  2020      1
# 5    예  2020      5
# 4    예  2019      1

# %%
main[main['취직여부']=='예']
# Out:
#   취직여부  졸업연도  타임스탬프
# 8    예  2023      1
# 7    예  2022      2
# 6    예  2021      5
# 5    예  2020      5
# 4    예  2019      1

# %%
main=pd.pivot_table(LIS, index=['취직여부','졸업연도'], values=['타임스탬프'], aggfunc='count')
main.reset_index(inplace=True)
main['졸업연도']=main['졸업연도'].astype(int)
main=main.sort_values('졸업연도', ascending=False)
#main.loc[2]=['예',2018,2]
#main=main.sort_values('졸업연도', ascending=False)
#main.drop('취직여부', axis=1, inplace=True)
main.rename(columns={'취직여부':'취직여부', '타임스탬프':'카운트', '졸업연도':'연도'}, inplace=True)
#main1=main.iloc[[1,0]]
#main2=main.iloc[[2,3,4,5]]
main2 = main[main['취직여부']=='예']
main1 = main[main['취직여부']=='아니오']
main1['구분']='취준생'
main2['구분']='취업자'
main1.drop('취직여부', axis=1, inplace=True)
main2.drop('취직여부', axis=1, inplace=True)
# Out:
# <ipython-input-54-471b7d8307ca>:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-54-471b7d8307ca>:14: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-54-471b7d8307ca>:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
main1
# Out:
#      연도  카운트   구분
# 3  2023    4  취준생
# 2  2022    1  취준생
# 1  2021    1  취준생
# 0  2020    1  취준생

# %%
main1=add_classes(main1, '취준생', '졸업연도', '졸업연도')
main1=main1.sort_values('연도', ascending=True)
main2=add_classes(main2, '취업자', '졸업연도', '졸업연도')
main2=main2.sort_values('연도', ascending=True)

enter_year2=Uenter_year.copy()
enter_year2.rename(columns={'입학연도':'연도'}, inplace=True)
enter_year2=enter_year2.sort_values('연도', ascending=True)

enter_year3=Genter_year.copy()
enter_year3.rename(columns={'대학원 입학연도':'연도'}, inplace=True)
enter_year3=enter_year3.sort_values('연도', ascending=True)

main_t=pd.concat([enter_year2,enter_year3,main2,main1], axis=0)
main_t['연도']=main_t['연도'].astype(str)
main_t=main_t.sort_values('연도', ascending=True)
main_t
# Out:
# <ipython-input-37-634a4c317377>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-37-634a4c317377>:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-37-634a4c317377>:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
make_color=[px.colors.sequential.deep[9],px.colors.sequential.deep[8],px.colors.sequential.deep[7],px.colors.sequential.deep[6],px.colors.sequential.deep[5],
        px.colors.sequential.deep[4],px.colors.sequential.deep[3], px.colors.sequential.deep[2], px.colors.sequential.deep[1], px.colors.sequential.deep[0]]

fig = px.bar(main_t, x="퍼센트(%)", y="구분", color='연도', orientation='h', text='연도',
      height=500,
      color_discrete_sequence=make_color,
      custom_data=['카운트','연도'])

fig.update_layout(xaxis_tickfont_size=12,plot_bgcolor='rgba(0, 0, 0, 0)', paper_bgcolor = 'rgba(0,0,0,0)',
                  legend_title_text='입학연도',
                  legend=dict(yanchor="top", y=1.25, xanchor="left",x=0 ,orientation="h",font_size=11, font_color='black'),
                  yaxis={'visible': True, 'showticklabels': True,  'title':''},
                  xaxis={'visible': False, 'showticklabels': False}, height=400,
                  font=dict(size=12, color="black"),margin=dict(t=0)
                  )

fig.update_traces(textposition='inside',textfont_size=10)
fig.update_traces(hovertemplate='<br>%{customdata[1]}</br>응답 건수: %{customdata[0]} 건 <br>' )
#fig.for_each_trace(lambda t: t.update(name=t.name.split("=")[1])) 오류나서 일단 주석처리

fig.show()

fig.write_html("연도.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
create_chart(main_t, '연도')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#레포트용 그래프(1)


make_color=[px.colors.sequential.deep[9],px.colors.sequential.deep[8],px.colors.sequential.deep[7],px.colors.sequential.deep[6],px.colors.sequential.deep[5],
        px.colors.sequential.deep[4],px.colors.sequential.deep[3], px.colors.sequential.deep[2], px.colors.sequential.deep[1], px.colors.sequential.deep[0]]

fig = px.bar(main_t, x="퍼센트(%)", y="구분", color='연도', orientation='h', text='연도',
      height=300,
      color_discrete_sequence=make_color,
      custom_data=['카운트','연도'])

fig.update_layout(xaxis_tickfont_size=12,plot_bgcolor="#FFFFFF",
                legend_title_text='입학연도',
                legend=dict(yanchor="top", y=1.45,xanchor="left",x=0.0,orientation="h",font_size=12),
                yaxis={'visible': True, 'showticklabels': True,  'title':''},
                xaxis={'visible': False, 'showticklabels': False},
                )

fig.update_traces(textposition='inside',textfont_size=12)
fig.update_traces(hovertemplate='<br>%{customdata[1]}</br>응답 건수: %{customdata[0]} 건 <br>' )
#fig.for_each_trace(lambda t: t.update(name=t.name.split("=")[1]))

fig.show()

fig.write_html("연도.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#레포트용 그래프(2)

make_color=[px.colors.sequential.deep[9],px.colors.sequential.deep[8],px.colors.sequential.deep[7],px.colors.sequential.deep[6],px.colors.sequential.deep[5],
         px.colors.sequential.deep[4],px.colors.sequential.deep[3], px.colors.sequential.deep[2], px.colors.sequential.deep[1], px.colors.sequential.deep[0]]
fig = px.bar(main_t, x="퍼센트(%)", y="구분", color='연도', orientation='h', text='연도',
       height=300,
       color_discrete_sequence=make_color,
       custom_data=['카운트','연도'])

fig.update_layout(xaxis_tickfont_size=12,plot_bgcolor="rgba(0,0,0,0)", paper_bgcolor = 'rgba(0,0,0,0)',
                 legend_title_text='입학연도',
                 legend=dict(yanchor="top", y=1.45,orientation="h",font_size=12),#, font_color='white'),
                 yaxis={'visible': True, 'showticklabels': True,  'title':''},
                 xaxis={'visible': False, 'showticklabels': False},
                 font=dict(size=12)#, color="white")
                 )
fig.update_traces(textposition='inside',textfont_size=12)
fig.update_traces(hovertemplate='<br>%{customdata[1]}</br>응답 건수: %{customdata[0]} 건 <br>' )
# fig.for_each_trace(lambda t: t.update(name=t.name.split("=")[1]))

fig.show()

fig.write_html("연도.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **(d)졸업생 (취준생, 취업자)**

# %%
employed_yn=count_to(LIS['취직여부'], '취직여부')
employed_yn.loc[0]=['취업자', count_to(LIS['취직여부'], '취직여부').iloc[0,1]]
employed_yn.loc[1]=['취준생', count_to(LIS['취직여부'], '취직여부').iloc[1,1]]
employed_yn
# Out:
#   취직여부  카운트
# 0  취업자   14
# 1  취준생    7

# %%
gender=count_to(LIS['성별'], '성별')
gender
# Out:
#       성별  카운트
# 0     여성   67
# 1     남성   24
# 2  선택 안함    3

# %%
grade=count_to(LIS['학년'], '학년')
grade=grade.sort_values('학년', ascending=True)
grade
# Out:
#               학년  카운트
# 2  1학년 (1~2차 학기)   16
# 3  2학년 (3~4차 학기)   13
# 1  3학년 (5~6차 학기)   16
# 0  4학년 (7~8차 학기)   19
# 4       9차 학기 이상    3

# %% [markdown]
# # 결과 분석

# %% [markdown]
# # (1) 학부 재학생 개별 질문

# %% [markdown]
# ### 학부 재학생 희망 진로 관련

# %% [markdown]
# **입학 당시 희망진로 유무**</n>
#
# **U011)입학 당시 희망 진로가 있었나요?**

# %%
DF_U011=count_to(Ustudent['입학당시희망진로유무'], '희망진로유무')
DF_U011=add_classes(DF_U011,'재학생','희망진로유무','희망진로유무')
DF_U011
# Out:
#   희망진로유무  카운트   구분  퍼센트(%)
# 0      예   44  재학생   65.67
# 1    아니오   23  재학생   34.33

# %%
create_chart_layout(DF_U011, '희망진로유무')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **입학 당시 희망진로 종류**</n>
#
# **U011.1)입학 당시 희망 진로는 무엇이었나요?(복수응답 가능)**

# %%
DF_U011_1=count_to(Ustudent['입학당시희망진로'], '입학당시희망진로')

#같은 선택지인데 다르게 카운트 되는 부분이 있음. 예외 처리하기 함수
DF_U011_1=count_to_outlier(DF_U011_1, '입학당시희망진로')
DF_U011_1=DF_U011_1.sort_values('카운트', ascending=False)

DF_U011_1=add_classes(DF_U011_1,'학부 재학생','입학당시희망진로','입학당시희망진로')
DF_U011_1
# Out:
#                        입학당시희망진로  카운트      구분  퍼센트(%)
# 0                   개발자 (프로그래머)    2  학부 재학생   11.76
# 1                       데이터 전문가    2  학부 재학생   11.76
# 2                         사서 교사    2  학부 재학생   11.76
# 3                        일반 사기업    2  학부 재학생   11.76
# 4                           공기업    1  학부 재학생    5.88
# 5                  공무원 (사서직 제외)    1  학부 재학생    5.88
# 6                       기록물 관리사    1  학부 재학생    5.88
# 7                         대학 교수    1  학부 재학생    5.88
# 8                           로스쿨    1  학부 재학생    5.88
# 9   사서직 (공무원/대학 및 전문 도서관 사서 포함)    1  학부 재학생    5.88
# 10                          언론인    1  학부 재학생    5.88
# 11                          자영업    1  학부 재학생    5.88
# 12                          출판업    1  학부 재학생    5.88

# %% [markdown]
# **현재 희망 진로 유무 여부**</b>
#
# **012) 현재 희망 진로가 있나요?**

# %%
DF_U012=count_to(Ustudent['현재희망진로유무'], '현재희망진로유무')
DF_U012=add_classes(DF_U012,'학부 재학생','현재희망진로유무','현재희망진로유무')
DF_U012
# Out:
#   현재희망진로유무  카운트      구분  퍼센트(%)
# 0        예   47  학부 재학생   70.15
# 1      아니오   20  학부 재학생   29.85

# %%
create_chart_layout(DF_U012, '현재희망진로유무')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **현재 희망 진로 종류**</b>
#
# **U012.1) 현재 희망 진로는 무엇인가요?(복수응답 가능)**

# %%
DF_U012_1=count_to(Ustudent['현재희망진로'], '현재희망진로')

#같은 선택지인데 다르게 카운트 되는 부분이 있음. 예외 처리하기 함수
DF_U012_1 = count_to_outlier2(DF_U012_1, '현재희망진로')
DF_U012_1=DF_U012_1.sort_values('카운트', ascending=False)
DF_U012_1.reset_index(inplace=True)

#기타 만들어주기 (승무원, 언론인, 콘텐츠 매니저 창업, 회계사 -> 기타로 넣어줌)
DF_U012_1.drop(labels=range(12,16), inplace=True)
DF_U012_1.loc[12]=['기타', 4]

s_df4=add_classes(DF_U012_1,'학부 재학생','현재희망진로','현재희망진로')
DF_U012_1
# Out:
#                          현재희망진로  카운트      구분  퍼센트(%)
# 0                        일반 사기업   23  학부 재학생   20.91
# 1   사서직 (공무원/대학 및 전문 도서관 사서 포함)   18  학부 재학생   16.36
# 2                       데이터 전문가   16  학부 재학생   14.55
# 3                   개발자 (프로그래머)   11  학부 재학생   10.00
# 4                           공기업    9  학부 재학생    8.18
# 5                         사서 교사    7  학부 재학생    6.36
# 6                  공무원 (사서직 제외)    6  학부 재학생    5.45
# 7                       기록물 관리사    4  학부 재학생    3.64
# 8                         대학 교수    4  학부 재학생    3.64
# 12                           기타    4  학부 재학생    3.64
# 9                           자영업    3  학부 재학생    2.73
# 10                          출판업    3  학부 재학생    2.73
# 11                          로스쿨    2  학부 재학생    1.82

# %%
# 입학당시/현재 희망진로한 그래프에 나타내기
fig = go.Figure(data=[
    #go.Bar(name='입학당시 희망진로', x=s_df2['희망진로_입학'], y=s_df2['카운트'],marker=dict(color=new[2]),hovertemplate = '<b>재학생의 <br>%{customdata}(%)<br> 응답 건수: %{y:.2f}건<extra></extra>',customdata=s_df2['퍼센트(%)']),
    #go.Bar(name='현재 희망진로',  x=s_df4['희망진로_현재'], y=s_df4['카운트'],marker=dict(color=new[7]),hovertemplate = '<b>재학생의 <br>%{customdata}(%)<br>응답 건수: %{y:.2f}건<extra></extra>',customdata=s_df4['퍼센트(%)'])
    go.Bar(name='현재 희망진로',  x=DF_U012_1['현재희망진로'], y=DF_U012_1['퍼센트(%)'],marker=dict(color=px.colors.sequential.deep[7]),hovertemplate = '응답 건수: %{customdata}건<extra></extra>',customdata=DF_U012_1['카운트'], text=DF_U012_1['퍼센트(%)']),
    go.Bar(name='입학당시 희망진로', x=DF_U011_1['입학당시희망진로'], y=DF_U011_1['퍼센트(%)'],marker=dict(color=px.colors.sequential.deep[1]),hovertemplate = '응답 건수: %{customdata}건<extra></extra>',customdata=DF_U011_1['카운트'], text=DF_U011_1['퍼센트(%)'])

])

fig.update_layout(barmode='group',
                  bargap=0.15,
                  height=450,width=1700,
                  yaxis={'visible': False, 'showticklabels': False},
                  xaxis={'visible': True, 'showticklabels': True},
                  showlegend=True,margin=dict(l=2, r=2),
                  plot_bgcolor='rgba(0, 0, 0, 0)', paper_bgcolor = 'rgba(0,0,0,0)',
                  legend=dict(
                      orientation="h",
                      yanchor= "top",
                      y=1.1,
                      xanchor= "left",
                      x=0.01
                      ))

fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside',textfont_size=11.2 )
fig.write_html("U_입학현재희망진로비교.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 레포트용 시각화
fig = go.Figure(data=[
    go.Bar(name='현재 희망진로',  x=DF_U012_1['현재희망진로'], y=DF_U012_1['퍼센트(%)'],marker=dict(color=px.colors.sequential.deep[8]),hovertemplate = '응답 건수: %{customdata}건<extra></extra>',customdata=DF_U012_1['카운트'], text=DF_U012_1['퍼센트(%)']),
    go.Bar(name='입학당시 희망진로', x=DF_U011_1['입학당시희망진로'], y=DF_U011_1['퍼센트(%)'],marker=dict(color='#BDBDBD'),hovertemplate = '응답 건수: %{customdata}건<extra></extra>',customdata=DF_U011_1['카운트'], text=DF_U011_1['퍼센트(%)'])

])

fig.update_layout(barmode='group',
                  bargap=0.1,
                  height=500,width=1700,
                  yaxis={'visible': False, 'showticklabels': False},
                  xaxis={'visible': True, 'showticklabels': True},
                  showlegend=True,
                  plot_bgcolor="#FFFFFF",
                  legend=dict(
                      orientation="h",
                      yanchor= "top",
                      y=1.1,
                      xanchor= "left",
                      x=0.01
                      ))

fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside',textfont_size=11.2 )
fig.show()
fig.write_html("hope_job.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#레포트용 그래프
fig = go.Figure(data=[
    go.Bar(name='현재 희망진로',  x=DF_U012_1['현재희망진로'], y=DF_U012_1['퍼센트(%)'],marker=dict(color=px.colors.sequential.deep[8]),hovertemplate = '응답 건수: %{customdata}건<extra></extra>',customdata=DF_U012_1['카운트'], text=DF_U012_1['퍼센트(%)']),

])

fig.update_layout(bargap=0.15,
                  height=500,width=1400,
                  yaxis={'visible': False, 'showticklabels': False},
                  xaxis={'visible': True, 'showticklabels': True},
                  showlegend=True,
                  plot_bgcolor="#FFFFFF",
                  legend=dict(
                      orientation="h",
                      yanchor= "top",
                      y=1.1,
                      xanchor= "left",
                      x=0.01
                      ))

fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside',textfont_size=11.2 )
fig.show()
fig.write_html("hope_job.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **현재 희망 진로가 없는 이유**
#
# **U012.2)현재 희망 진로가 없다면 그 이유는 무엇인가요?(복수 응답 가능)**

# %%
DF_U012_2=count_to(Ustudent['현재희망진로없는이유'], '현재희망진로없는이유')

#같은 선택지인데 다르게 카운트 되는 부분이 있음. 예외 처리하기 함수
DF_U012_2 = count_to_outlier2(DF_U012_2, '현재희망진로없는이유')
DF_U012_2.reset_index(inplace=True)
DF_U012_2=DF_U012_2.sort_values('카운트', ascending=True)
DF_U012_2=add_classes(DF_U012_2,'재학생','현재희망진로없는이유','현재희망진로없는이유')
DF_U012_2
# Out:
#                        현재희망진로없는이유  카운트   구분  퍼센트(%)
# 4              본인이 아직 뭘 잘하는지 잘 모름   17  재학생   34.69
# 3             본인이 아직 뭘 좋아하는지 잘 모름   13  재학생   26.53
# 2     개인의 삶의 방향에 대한 가치관이 정립되지 않았음   11  재학생   22.45
# 1  문헌정보학 전공자가 진출 가능한 분야에 대한 정보 부족    5  재학생   10.20
# 0            아직 진로에 대해 고민하지 않고 있음    3  재학생    6.12

# %%
# 아니오랑 색깔 맞춰줌
DF_U012_2.sort_values(by='퍼센트(%)',ascending=True,inplace=True)
fig=px.bar(DF_U012_2, x='퍼센트(%)', y='현재희망진로없는이유', orientation='h', color_discrete_sequence=[px.colors.sequential.deep[1]],
           custom_data=['카운트'], text='퍼센트(%)')

fig.update_layout(height=400,width=750,
                  yaxis={'visible': True, 'showticklabels': True,  'title':''},
                  xaxis={'visible': False, 'showticklabels': False},
                  showlegend=True,margin=dict(l=2, r=2), font=dict(size=10, color="black"),
                  plot_bgcolor='rgba(0, 0, 0, 0)', paper_bgcolor = 'rgba(0,0,0,0)',)

fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside',textfont_size=14 )
#fig.update_traces(hovertemplate='<br>현재희망진로가 없는 이유</br><br> 재학생의 %{x} % <br> 응답 건수: %{customdata[0]} 건 <br>')
fig.update_traces(hovertemplate='응답 건수: %{customdata[0]} 건 <br>')
fig.update_yaxes(tickfont=dict(size=14))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_html("U_희망진로없는이유.html")

# %% [markdown]
# **입학당시와 현재의 희망진로가 달라진 이유**
#
# **U013)입학당시와 현재의 희망진로가 다르다면, 그 이유는 무엇인가요?**

# %%
DF_U013=count_to(Ustudent['희망진로불일치이유'], '희망진로불일치이유')

#같은 선택지인데 다르게 카운트 되는 부분이 있음. 예외 처리하기 함수
DF_U013 = count_to_outlier2(DF_U013, '희망진로불일치이유')
DF_U013.sort_values(by='카운트', ascending=False, inplace=True)
DF_U013.reset_index(inplace=True)

# 교직이수에 성공해버려, 크게 다르지 않지만 가능성이 더 늘어난 것을 알게 됨 > 기타로 넣어주기
DF_U013.loc[7] = ['기타', 2]
DF_U013.drop([5,6], inplace = True)

DF_U013=add_classes(DF_U013,'학부 재학생','희망진로불일치이유','희망진로불일치이유')
DF_U013.sort_values(by='카운트', ascending=True, inplace=True)
DF_U013
# Out:
#             희망진로불일치이유  카운트      구분  퍼센트(%)
# 5                  기타    2  학부 재학생    2.27
# 4  학과 관련 직무에 대한 흥미 잃음    9  학부 재학생   10.23
# 3   희망 진로가 두 시기 모두 없음   10  학부 재학생   11.36
# 2  희망 진로가 두 시기 다르지 않음   14  학부 재학생   15.91
# 1          현실적인 한계 인식   26  학부 재학생   29.55
# 0     새로운 적성/관심 분야 파악   27  학부 재학생   30.68

# %%
fig=px.bar(DF_U013, x='퍼센트(%)', y='희망진로불일치이유', orientation='h',  color_discrete_sequence=[new[5]],
           text='퍼센트(%)')

fig.update_layout(height=400,width=750,
                  yaxis={'visible': True, 'showticklabels': True,  'title':''},
                  xaxis={'visible': False, 'showticklabels': False},
                  showlegend=True, margin=dict(l=2, r=2),
                  plot_bgcolor='rgba(0, 0, 0, 0)', paper_bgcolor = 'rgba(0,0,0,0)')

fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside',textfont_size=13 )
#fig.update_traces(hovertemplate='<br>평소 진로관련 고민</br> <br> 재학생의 %{x} % <br> 응답 건수: %{customdata} 건 <br>',customdata=s_df7['카운트'] )
fig.update_traces(hovertemplate='응답 건수: %{customdata} 건 <br>',customdata=DF_U013['카운트'] )
fig.update_yaxes(tickfont=dict(size=13))
fig.show()
fig.write_html("U_희망진로불일치이유.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **U014)입학당시와 현재의 희망진로가 달라진 것에 영향을 준 것은 무엇인가요?**

# %%
DF_U014=count_to(Ustudent['희망진로불일치영향'], '희망진로불일치영향')

#같은 선택지인데 다르게 카운트 되는 부분이 있음. 예외 처리하기 함수
DF_U014 = count_to_outlier2(DF_U014, '희망진로불일치영향')
DF_U014.sort_values(by='카운트', ascending=False, inplace=True)
DF_U014.reset_index(inplace=True)

#도서관 실습, 비슷한 진로를 희망하던 지인의 모습, 흥미를 잃음 > 기타로 넣어주기
DF_U014.loc[21] = ['기타', 3]
DF_U014.drop([18, 19, 20], inplace = True)

DF_U014=add_classes(DF_U014,'재학생','희망진로불일치영향','희망진로불일치영향')
DF_U014.sort_values(by='카운트', ascending=True, inplace=True)
DF_U014
# Out:
#              희망진로불일치영향  카운트   구분  퍼센트(%)
# 17           교직 이수 불합격    2  재학생    1.31
# 16             교환학생 경험    2  재학생    1.31
# 18                  기타    3  재학생    1.96
# 15               아르바이트    5  재학생    3.27
# 14                 부모님    5  재학생    3.27
# 13              학회/소모임    6  재학생    3.92
# 12                  학점    6  재학생    3.92
# 11                  친구    6  재학생    3.92
# 10                 동아리    6  재학생    3.92
# 7                   인턴    7  재학생    4.58
# 8             공모전/프로젝트    7  재학생    4.58
# 9                   선배    7  재학생    4.58
# 6                 대외활동    8  재학생    5.23
# 5    희망 진로가 두 시기 모두 없음    8  재학생    5.23
# 4                  교수님    9  재학생    5.88
# 3   희망 진로가 두 시기 다르지 않음   10  재학생    6.54
# 2                타과 수업   13  재학생    8.50
# 1          진로 관련 정보 탐색   19  재학생   12.42
# 0            문헌정보학과 수업   24  재학생   15.69

# %%
fig=px.bar(DF_U014, x='퍼센트(%)', y='희망진로불일치영향', color_discrete_sequence=[new[5]],
           text='퍼센트(%)')

fig.update_layout(height=500,width=900,
                  yaxis={'visible': True, 'showticklabels': True,  'title':''},
                  xaxis={'visible': False, 'showticklabels': False},
                  showlegend=True,plot_bgcolor='rgba(0, 0, 0, 0)', paper_bgcolor = 'rgba(0,0,0,0)')

fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside',textfont_size=13 )
#fig.update_traces(hovertemplate='<br>평소 진로관련 고민</br> <br> 재학생의 %{x} % <br> 응답 건수: %{customdata} 건 <br>',customdata=s_df7['카운트'] )
fig.update_traces(hovertemplate='응답 건수: %{customdata} 건 <br>',customdata=DF_U014['카운트'] )
fig.update_yaxes(tickfont=dict(size=13))
fig.show()
fig.write_html("U_희망진로불일치영향.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 진로 고민 관련

# %% [markdown]
# **진로관련 고민**</b>
#
# **021)평소 진로에 있어서 고민이 있다면 무엇인가요?(복수 응답 가능)**

# %%
DF_U021=count_to(Ustudent['평소진로고민'], '평소진로고민')

# 같은 선택지인데 다르게 카운트 되는 부분이 있음. 예외 처리하기
DF_U021 = count_to_outlier2(DF_U021, '평소진로고민')
DF_U021=DF_U021.sort_values('카운트', ascending=True)
DF_U021.reset_index(inplace=True)

# 기타 만들어주기
# 사서의 현실적인 어려움(낮은 임금 등)에 대한 고민, 티오가 너무 없다, 학점 및 스펙 등
DF_U021.drop(labels=range(0,4), inplace=True)
DF_U021.loc[0] = ['기타', 3]
DF_U021.reset_index(inplace=True, drop=True)

DF_U021 = DF_U021[['평소진로고민', '카운트']]

DF_U021=add_classes(DF_U021,'학부 재학생','평소진로고민','평소진로관련고민')
DF_U021=DF_U021.sort_values('카운트', ascending=True)
DF_U021
# Out:
#                             평소진로관련고민  카운트      구분  퍼센트(%)
# 3                                 기타    3  학부 재학생    3.70
# 0                진로에 대한 정보를 얻을 곳이 없다    8  학부 재학생    9.88
# 1                   관심 분야가 무엇인지 모르겠다   23  학부 재학생   28.40
# 2  진로에 대한 생각은 하고 있는데 뚜렷한 방향을 잡을 수 없다   47  학부 재학생   58.02

# %%
fig=px.bar(DF_U021, x='퍼센트(%)', y='평소진로관련고민', orientation='h',  color_discrete_sequence=[new[5]],
           text='퍼센트(%)')

fig.update_layout(height=400,width=750,
                  yaxis={'visible': True, 'showticklabels': True,  'title':''},
                  xaxis={'visible': False, 'showticklabels': False},
                  showlegend=True, margin=dict(l=2, r=2),
                  plot_bgcolor='rgba(0, 0, 0, 0)', paper_bgcolor = 'rgba(0,0,0,0)')

fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside',textfont_size=13 )
#fig.update_traces(hovertemplate='<br>평소 진로관련 고민</br> <br> 재학생의 %{x} % <br> 응답 건수: %{customdata} 건 <br>',customdata=s_df7['카운트'] )
fig.update_traces(hovertemplate='응답 건수: %{customdata} 건 <br>',customdata=DF_U021['카운트'] )
fig.update_yaxes(tickfont=dict(size=13))
fig.show()
fig.write_html("U_평소진로관련고민.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **진로관련 고민 해결 방법**</b>
#
# **U022)평소 진로 관련 고민을 어떤 방식으로 해결하나요?(복수 응답 가능)**

# %%
DF_U022=count_to(Ustudent['진로고민해결방법'], '진로고민해결방법')

#같은 선택지인데 다르게 카운트 되는 부분이 있음. 예외 처리하기
DF_U022 = count_to_outlier2(DF_U022, '진로고민해결방법')
DF_U022.sort_values(by='카운트', ascending=False, inplace=True)
DF_U022.reset_index(inplace=True)

# 고민을 외면하고 해야할 일을 한다, 대외활동 > 기타로 넣어주기
DF_U022.loc[10] = ['기타', 2]
DF_U022.drop([7,9], inplace = True)

DF_U022=add_classes(DF_U022,'학부 재학생','진로고민해결방법','진로고민해결방법')
DF_U022=DF_U022.sort_values('카운트', ascending=True)
DF_U022
# Out:
#             진로고민해결방법  카운트      구분  퍼센트(%)
# 7             고민이 없다    1  학부 재학생    0.62
# 6  학교 취업 상담 센터를 활용한다    2  학부 재학생    1.25
# 8                 기타    2  학부 재학생    1.25
# 5     교수님께 상담 신청을 한다    6  학부 재학생    3.75
# 4       에브리타임에서 찾아본다    7  학부 재학생    4.38
# 3          선배들과 의논한다   13  학부 재학생    8.12
# 2            혼자 고민한다   36  학부 재학생   22.50
# 1          친구들과 의논한다   41  학부 재학생   25.62
# 0           자료를 찾아본다   52  학부 재학생   32.50

# %%
DF_U022.sort_values(by='퍼센트(%)',ascending=True,inplace=True)
fig=px.bar(DF_U022, x='퍼센트(%)', y='진로고민해결방법', orientation='h',  color_discrete_sequence=[new[5]],
           text='퍼센트(%)')

fig.update_layout(height=400,width=700,
                  title_font=dict(size=17,color='black'),
                  yaxis={'visible': True, 'showticklabels': True,  'title':''},
                  xaxis={'visible': False, 'showticklabels': False},
                  showlegend=True, margin=dict(l=2, r=2),
                  plot_bgcolor='rgba(0, 0, 0, 0)', paper_bgcolor = 'rgba(0,0,0,0)')

fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside',textfont_size=13 )
#fig.update_traces(hovertemplate='<br>평소 진로관련 고민 해결방법</br><br> 재학생의 %{x} % <br> 응답 건수: %{customdata} 건 <br>',customdata=s_df8['카운트'] )
fig.update_traces(hovertemplate='응답 건수: %{customdata} 건 <br>',customdata=DF_U022['카운트'] )
fig.update_yaxes(tickfont=dict(size=14))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_html("U_진로고민해결방법.html")

# %% [markdown]
# # (2) 대학원 재학생 개별 질문

# %% [markdown]
# ### 대학원 재학생 희망 진로 관련

# %% [markdown]
# **입학 당시 희망진로 유무**</b>
#
# **G011) 입학 당시 희망 진로가 있었나요?**

# %%
DF_G011=count_to(Gstudent['입학당시희망진로유무'], '입학당시희망진로유무')
DF_G011=add_classes(DF_G011,'대학원 재학생','희망진로유무','희망진로유무')
DF_G011
# Out:
#   입학당시희망진로유무  카운트       구분  퍼센트(%)
# 0          예    4  대학원 재학생   66.67
# 1        아니오    2  대학원 재학생   33.33

# %%
create_chart_layout(DF_G011, '입학당시희망진로유무')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **입학 당시 희망진로 종류**</b>
#
# **G011.1)입학 당시 희망 진로는 무엇이었나요?(복수 응답 가능)**

# %%
DF_G011_1=count_to(Gstudent['입학당시희망진로'], '입학당시희망진로')

#같은 선택지인데 다르게 카운트 되는 부분이 있음. 예외 처리하기 함수
DF_G011_1 = count_to_outlier2(DF_G011_1, '입학당시희망진로')
DF_G011_1=DF_G011_1.sort_values('카운트', ascending=False)
DF_G011_1.reset_index(inplace=True)

DF_G011_1=add_classes(DF_G011_1,'대학원 재학생','입학당시희망진로','입학당시희망진로')
DF_G011_1
# Out:
#                       입학당시희망진로  카운트       구분  퍼센트(%)
# 0  사서직 (공무원/대학 및 전문 도서관 사서 포함)    3  대학원 재학생   25.00
# 1                        대학 교수    2  대학원 재학생   16.67
# 2                        사서 교사    2  대학원 재학생   16.67
# 3                          공기업    1  대학원 재학생    8.33
# 4                      기록물 관리사    1  대학원 재학생    8.33
# 5                      데이터 전문가    1  대학원 재학생    8.33
# 6                       일반 사기업    1  대학원 재학생    8.33
# 7                          출판업    1  대학원 재학생    8.33

# %% [markdown]
# **현재 희망 진로 유무 여부**</b>
#
# **G012)현재 희망 진로가 있나요?**

# %%
DF_G012=count_to(Gstudent['현재희망진로유무'], '현재희망진로유무')
DF_G012=add_classes(DF_G012,'대학원 재학생','현재희망진로유무','현재희망진로유무')
DF_G012
# Out:
#   현재희망진로유무  카운트       구분  퍼센트(%)
# 0        예    5  대학원 재학생   83.33
# 1      아니오    1  대학원 재학생   16.67

# %%
create_chart_layout(DF_U012, '현재희망진로유무')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_html("G_현재희망진로유무.html")

# %% [markdown]
# **현재 희망 진로 종류**
#
# **G012.1)현재 희망 진로는 무엇인가요?(복수 응답 가능)**

# %%
DF_G012_1=count_to(Gstudent['현재희망진로'], '현재희망진로')

#같은 선택지인데 다르게 카운트 되는 부분이 있음. 예외 처리하기 함수
DF_G012_1 = count_to_outlier2(DF_G012_1, '현재희망진로')
DF_G012_1=DF_G012_1.sort_values('카운트', ascending=False)
DF_G012_1.reset_index(inplace=True)

DF_G012_1.reset_index(inplace=True, drop=True)
DF_G012_1=add_classes(DF_G012_1,'재학생','현재희망진로','현재희망진로')
DF_G012_1
# Out:
#                         현재희망진로  카운트   구분  퍼센트(%)
# 0                      데이터 전문가    2  재학생    25.0
# 1  사서직 (공무원/대학 및 전문 도서관 사서 포함)    2  재학생    25.0
# 2                  개발자 (프로그래머)    1  재학생    12.5
# 3                        대학 교수    1  재학생    12.5
# 4                          연구직    1  재학생    12.5
# 5                       일반 사기업    1  재학생    12.5

# %% [markdown]
# **입학 당시 희망 진로 vs 현재 희망 진로**

# %%
# 입학당시/현재 희망진로한 그래프에 나타내기
fig = go.Figure(data=[
    #go.Bar(name='입학당시 희망진로', x=s_df2['희망진로_입학'], y=s_df2['카운트'],marker=dict(color=new[2]),hovertemplate = '<b>재학생의 <br>%{customdata}(%)<br> 응답 건수: %{y:.2f}건<extra></extra>',customdata=s_df2['퍼센트(%)']),
    #go.Bar(name='현재 희망진로',  x=s_df4['희망진로_현재'], y=s_df4['카운트'],marker=dict(color=new[7]),hovertemplate = '<b>재학생의 <br>%{customdata}(%)<br>응답 건수: %{y:.2f}건<extra></extra>',customdata=s_df4['퍼센트(%)'])
    go.Bar(name='현재 희망진로',  x=DF_G012_1['현재희망진로'], y=DF_G012_1['퍼센트(%)'],marker=dict(color=px.colors.sequential.deep[7]),hovertemplate = '응답 건수: %{customdata}건<extra></extra>',customdata=DF_G012_1['카운트'], text=DF_G012_1['퍼센트(%)']),
    go.Bar(name='입학당시 희망진로', x=DF_G011_1['입학당시희망진로'], y=DF_G011_1['퍼센트(%)'],marker=dict(color=px.colors.sequential.deep[1]),hovertemplate = '응답 건수: %{customdata}건<extra></extra>',customdata=DF_G011_1['카운트'], text=DF_G011_1['퍼센트(%)'])

])

fig.update_layout(barmode='group',
                  bargap=0.15,
                  height=450,width=1700,
                  yaxis={'visible': False, 'showticklabels': False},
                  xaxis={'visible': True, 'showticklabels': True},
                  showlegend=True,margin=dict(l=2, r=2),
                  plot_bgcolor='rgba(0, 0, 0, 0)', paper_bgcolor = 'rgba(0,0,0,0)',
                  legend=dict(
                      orientation="h",
                      yanchor= "top",
                      y=1.1,
                      xanchor= "left",
                      x=0.01
                      ))

fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside',textfont_size=11.2 )
fig.write_html("U_입학현재희망진로비교.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 레포트용 시각화
fig = go.Figure(data=[
    go.Bar(name='현재 희망진로',  x=DF_G012_1['현재희망진로'], y=DF_G012_1['퍼센트(%)'],marker=dict(color=px.colors.sequential.deep[8]),hovertemplate = '응답 건수: %{customdata}건<extra></extra>',customdata=DF_G012_1['카운트'], text=DF_G012_1['퍼센트(%)']),
    go.Bar(name='입학당시 희망진로', x=DF_G011_1['입학당시희망진로'], y=DF_G011_1['퍼센트(%)'],marker=dict(color='#BDBDBD'),hovertemplate = '응답 건수: %{customdata}건<extra></extra>',customdata=DF_G011_1['카운트'], text=DF_G011_1['퍼센트(%)'])

])

fig.update_layout(barmode='group',
                  bargap=0.1,
                  height=500,width=1700,
                  yaxis={'visible': False, 'showticklabels': False},
                  xaxis={'visible': True, 'showticklabels': True},
                  showlegend=True,
                  plot_bgcolor="#FFFFFF",
                  legend=dict(
                      orientation="h",
                      yanchor= "top",
                      y=1.1,
                      xanchor= "left",
                      x=0.01
                      ))

fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside',textfont_size=11.2 )
fig.show()
fig.write_html("hope_job.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#레포트용 그래프
fig = go.Figure(data=[
    go.Bar(name='현재 희망진로',  x=DF_G012_1['현재희망진로'], y=DF_G012_1['퍼센트(%)'],marker=dict(color=px.colors.sequential.deep[8]),hovertemplate = '응답 건수: %{customdata}건<extra></extra>',customdata=DF_G012_1['카운트'], text=DF_G012_1['퍼센트(%)']),

])

fig.update_layout(bargap=0.15,
                  height=500,width=1400,
                  yaxis={'visible': False, 'showticklabels': False},
                  xaxis={'visible': True, 'showticklabels': True},
                  showlegend=True,
                  plot_bgcolor="#FFFFFF",
                  legend=dict(
                      orientation="h",
                      yanchor= "top",
                      y=1.1,
                      xanchor= "left",
                      x=0.01
                      ))

fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside',textfont_size=11.2 )
fig.show()
fig.write_html("hope_job.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **현재 희망 진로가 없는 이유**
#
# **G012.2) 현재 희망 진로가 없다면 그 이유는 무엇인가요?(복수 응답 가능)**

# %%
DF_G012_2=count_to(Gstudent['현재희망진로없는이유'], '현재희망진로없는이유')
DF_G012_2=add_classes(DF_G012_2,'대학원 재학생','현재희망진로없는이유','현재희망진로없는이유')
DF_G012_2
# Out:
#              현재희망진로없는이유  카운트       구분  퍼센트(%)
# 0  아직 진로에 대해 고민하지 않고 있음    1  대학원 재학생   100.0

# %% [markdown]
# 빼기

# %%
# 아니오랑 색깔 맞춰줌
DF_G012_2.sort_values(by='퍼센트(%)',ascending=True,inplace=True)
fig=px.bar(DF_G012_2, x='퍼센트(%)', y='현재희망진로없는이유', orientation='h', color_discrete_sequence=[px.colors.sequential.deep[1]],
           custom_data=['카운트'], text='퍼센트(%)')

fig.update_layout(height=400,width=750,
                  yaxis={'visible': True, 'showticklabels': True,  'title':''},
                  xaxis={'visible': False, 'showticklabels': False},
                  showlegend=True,margin=dict(l=2, r=2), font=dict(size=10, color="black"),
                  plot_bgcolor='rgba(0, 0, 0, 0)', paper_bgcolor = 'rgba(0,0,0,0)',)

fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside',textfont_size=14 )
#fig.update_traces(hovertemplate='<br>현재희망진로가 없는 이유</br><br> 재학생의 %{x} % <br> 응답 건수: %{customdata[0]} 건 <br>')
fig.update_traces(hovertemplate='응답 건수: %{customdata[0]} 건 <br>')
fig.update_yaxes(tickfont=dict(size=14))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_html("G_희망진로없는이유.html")

# %% [markdown]
# **입학 당시와 현재의 희망 진로가 달라진 이유**
#
# **G013) 입학 당시와 현재의 희망 진로가 다르다면, 그 이유가 무엇인가요?**

# %%
DF_G013=count_to(Gstudent['희망진로불일치이유'], '희망진로불일치이유')

#같은 선택지인데 다르게 카운트 되는 부분이 있음. 예외 처리하기 함수
DF_G013 = count_to_outlier2(DF_G013, '희망진로불일치이유')
DF_G013.sort_values(by='카운트', ascending=False, inplace=True)
DF_G013.reset_index(inplace=True)

DF_G013=add_classes(DF_G013,'대학원 재학생','희망진로불일치이유','희망진로불일치이유')
DF_G013.sort_values(by='카운트', ascending=True, inplace=True)
DF_G013
# Out:
#             희망진로불일치이유  카운트       구분  퍼센트(%)
# 2          현실적인 한계 인식    1  대학원 재학생   16.67
# 1  희망 진로가 두 시기 다르지 않음    2  대학원 재학생   33.33
# 0     새로운 적성/관심 분야 파악    3  대학원 재학생   50.00

# %%
fig=px.bar(DF_G013, x='퍼센트(%)', y='희망진로불일치이유', orientation='h',  color_discrete_sequence=[new[5]],
           text='퍼센트(%)')

fig.update_layout(height=400,width=750,
                  yaxis={'visible': True, 'showticklabels': True,  'title':''},
                  xaxis={'visible': False, 'showticklabels': False},
                  showlegend=True, margin=dict(l=2, r=2),
                  plot_bgcolor='rgba(0, 0, 0, 0)', paper_bgcolor = 'rgba(0,0,0,0)')

fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside',textfont_size=13 )
#fig.update_traces(hovertemplate='<br>평소 진로관련 고민</br> <br> 재학생의 %{x} % <br> 응답 건수: %{customdata} 건 <br>',customdata=s_df7['카운트'] )
fig.update_traces(hovertemplate='응답 건수: %{customdata} 건 <br>',customdata=DF_G013['카운트'] )
fig.update_yaxes(tickfont=dict(size=13))
fig.show()
fig.write_html("G_희망진로불일치이유.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **G014)입학당시와 현재의 희망진로가 달라진 것에 영향을 준 것은 무엇인가요?**

# %%
DF_G014=count_to(Gstudent['희망진로불일치영향'], '희망진로불일치영향')

#같은 선택지인데 다르게 카운트 되는 부분이 있음. 예외 처리하기 함수
DF_G014 = count_to_outlier2(DF_G014, '희망진로불일치영향')
DF_G014.sort_values(by='카운트', ascending=False, inplace=True)
DF_G014.reset_index(inplace=True)

DF_G014=add_classes(DF_G014,'재학생','희망진로불일치영향','희망진로불일치영향')
DF_G014.sort_values(by='카운트', ascending=True, inplace=True)
DF_G014
# Out:
#              희망진로불일치영향  카운트   구분  퍼센트(%)
# 5            교직 이수 불합격    1  재학생    5.88
# 6                  동아리    1  재학생    5.88
# 7            문헌정보학과 수업    1  재학생    5.88
# 8          진로 관련 정보 탐색    1  재학생    5.88
# 9                   친구    1  재학생    5.88
# 10              학회/소모임    1  재학생    5.88
# 1             공모전/프로젝트    2  재학생   11.76
# 2                   인턴    2  재학생   11.76
# 3                타과 수업    2  재학생   11.76
# 4   희망 진로가 두 시기 다르지 않음    2  재학생   11.76
# 0                  교수님    3  재학생   17.65

# %%
fig=px.bar(DF_G014, x='퍼센트(%)', y='희망진로불일치영향', color_discrete_sequence=[new[5]],
           text='퍼센트(%)')

fig.update_layout(height=500,width=900,
                  yaxis={'visible': True, 'showticklabels': True,  'title':''},
                  xaxis={'visible': False, 'showticklabels': False},
                  showlegend=True,plot_bgcolor='rgba(0, 0, 0, 0)', paper_bgcolor = 'rgba(0,0,0,0)')

fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside',textfont_size=13 )
#fig.update_traces(hovertemplate='<br>평소 진로관련 고민</br> <br> 재학생의 %{x} % <br> 응답 건수: %{customdata} 건 <br>',customdata=s_df7['카운트'] )
fig.update_traces(hovertemplate='응답 건수: %{customdata} 건 <br>',customdata=DF_G014['카운트'] )
fig.update_yaxes(tickfont=dict(size=13))
fig.show()
fig.write_html("G_희망진로불일치영향.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 진로 고민 관련

# %% [markdown]
# **진로관련 고민**
#
# **G021)평소 진로에 있어서 고민이 있다면 무엇인가요?(복수 응답 가능)**

# %%
DF_G021=count_to(Gstudent['평소진로고민'], '평소진로고민')

# 같은 선택지인데 다르게 카운트 되는 부분이 있음. 예외 처리하기
DF_G021 = count_to_outlier2(DF_G021, '평소진로고민')
DF_G021=DF_G021.sort_values('카운트', ascending=True)
DF_G021.reset_index(inplace=True)

DF_G021 = DF_G021[['평소진로고민', '카운트']]

DF_G021=add_classes(DF_G021,'대학원 재학생','평소진로고민','평소진로관련고민')
DF_G021=DF_G021.sort_values('카운트', ascending=True)
DF_G021
# Out:
#                             평소진로관련고민  카운트       구분  퍼센트(%)
# 0                   관심 분야가 무엇인지 모르겠다    1  대학원 재학생    12.5
# 1                진로에 대한 정보를 얻을 곳이 없다    3  대학원 재학생    37.5
# 2  진로에 대한 생각은 하고 있는데 뚜렷한 방향을 잡을 수 없다    4  대학원 재학생    50.0

# %%
fig=px.bar(DF_G021, x='퍼센트(%)', y='평소진로관련고민', orientation='h',  color_discrete_sequence=[new[5]],
           text='퍼센트(%)')

fig.update_layout(height=400,width=750,
                  yaxis={'visible': True, 'showticklabels': True,  'title':''},
                  xaxis={'visible': False, 'showticklabels': False},
                  showlegend=True, margin=dict(l=2, r=2),
                  plot_bgcolor='rgba(0, 0, 0, 0)', paper_bgcolor = 'rgba(0,0,0,0)')

fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside',textfont_size=13 )
#fig.update_traces(hovertemplate='<br>평소 진로관련 고민</br> <br> 재학생의 %{x} % <br> 응답 건수: %{customdata} 건 <br>',customdata=s_df7['카운트'] )
fig.update_traces(hovertemplate='응답 건수: %{customdata} 건 <br>',customdata=DF_G021['카운트'] )
fig.update_yaxes(tickfont=dict(size=13))
fig.show()
fig.write_html("G_평소진로관련고민.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **진로 관련 고민 해결 방법**
#
# **G022)평소 진로 관련 고민을 어떤 방식으로 해결하나요?(복수 응답 가능)**

# %%
DF_G022=count_to(Gstudent['진로고민해결방법'], '진로고민해결방법')

#같은 선택지인데 다르게 카운트 되는 부분이 있음. 예외 처리하기
DF_G022 = count_to_outlier2(DF_G022, '진로고민해결방법')
DF_G022.sort_values(by='카운트', ascending=False, inplace=True)
DF_G022.reset_index(inplace=True)

#s_df8.reset_index(inplace=True, drop=True)
DF_G022=add_classes(DF_G022,'대학원 재학생','진로고민해결방법','진로고민해결방법')
DF_G022=DF_G022.sort_values('카운트', ascending=True)
DF_G022
# Out:
#          진로고민해결방법  카운트       구분  퍼센트(%)
# 3         혼자 고민한다    2  대학원 재학생   15.38
# 1  교수님께 상담 신청을 한다    3  대학원 재학생   23.08
# 2       친구들과 의논한다    3  대학원 재학생   23.08
# 0        자료를 찾아본다    5  대학원 재학생   38.46

# %%
DF_G022.sort_values(by='퍼센트(%)',ascending=True,inplace=True)
fig=px.bar(DF_G022, x='퍼센트(%)', y='진로고민해결방법', orientation='h',  color_discrete_sequence=[new[5]],
           text='퍼센트(%)')

fig.update_layout(height=400,width=700,
                  title_font=dict(size=17,color='black'),
                  yaxis={'visible': True, 'showticklabels': True,  'title':''},
                  xaxis={'visible': False, 'showticklabels': False},
                  showlegend=True, margin=dict(l=2, r=2),
                  plot_bgcolor='rgba(0, 0, 0, 0)', paper_bgcolor = 'rgba(0,0,0,0)')

fig.update_traces(texttemplate='%{text:.2f}%', textposition='inside',textfont_size=13 )
#fig.update_traces(hovertemplate='<br>평소 진로관련 고민 해결방법</br><br> 재학생의 %{x} % <br> 응답 건수: %{customdata} 건 <br>',customdata=s_df8['카운트'] )
fig.update_traces(hovertemplate='응답 건수: %{customdata} 건 <br>',customdata=DF_G022['카운트'] )
fig.update_yaxes(tickfont=dict(size=14))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_html("G_진로고민해결방법.html")
